# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import sklearn

# to split the dataset into test and train 
from sklearn.model_selection import train_test_split

# Transformers 
from sklearn.preprocessing import StandardScaler

# language Processing Libraries
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

import spacy

# Neural network libraries
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot

from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# %% [markdown]
# # Loading in the Dataset
# source: https://www.kaggle.com/kemical/kickstarter-projects/notebooks?sortBy=dateRun&group=upvoted&pageSize=20&datasetId=4104

# %%
# To view all the columns 
pd.set_option('display.max_columns', None)

df = pd.read_csv('kickstarter.csv', 
                parse_dates=['deadline', 'launched'])
df.head(5)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency   deadline     goal  \
# 0          Poetry    Publishing      GBP 2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD 2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD 2013-02-26  45000.0
# 3           Music         Music      USD 2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD 2015-08-29  19500.0
#
#              launched  pledged     state  backers country  usd pledged  \
# 0 2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# 1 2017-09-02 04:43:57   2421.0    failed       15      US        100.0
# 2 2013-01-12 00:20:50    220.0    failed        3      US        220.0
# 3 2012-03-17 03:24:11      1.0    failed        1      US          1.0
# 4 2015-07-04 08:35:03   1283.0  canceled       14      US       1283.0
#
#    usd_pledged_real  usd_goal_real
# 0               0.0        1533.95
# 1            2421.0       30000.00
# 2             220.0       45000.00
# 3               1.0        5000.00
# 4            1283.0       19500.00

# %% [markdown]
# Ideas:
# - delete ID
# - feature engineering (deadline and launched)
# - Consider top five countries
# - Only consider failed or successful and make it a binary classifictaion
# - Will keep all the 15 main categories
# - For category we could pass it to the ordinal encoding

# %% [markdown]
# # EDA

# %%
total_nan = df.isna().sum().sort_values(ascending=False)
percentage_nan = (total_nan / df.shape[0]) * 100
tabel = pd.concat([total_nan, percentage_nan], axis=1, keys=['Total NAN', 'Percentage of NAN'])
tabel
# Out:
#                   Total NAN  Percentage of NAN
# usd pledged            3797           1.002744
# name                      4           0.001056
# usd_goal_real             0           0.000000
# usd_pledged_real          0           0.000000
# country                   0           0.000000
# backers                   0           0.000000
# state                     0           0.000000
# pledged                   0           0.000000
# launched                  0           0.000000
# goal                      0           0.000000
# deadline                  0           0.000000
# currency                  0           0.000000
# main_category             0           0.000000
# category                  0           0.000000
# ID                        0           0.000000

# %%
df.state.value_counts()
# Out:
# failed        197719
# successful    133956
# canceled       38779
# undefined       3562
# live            2799
# suspended       1846
# Name: state, dtype: int64

# %%
# filtering out the dataset for binary target variable - failed / successful
df = df.loc[(df['state'] == 'failed') | (df['state'] == 'successful')]
df.state.value_counts()
# Out:
# failed        197719
# successful    133956
# Name: state, dtype: int64

# %%
# Imbalance classification but not worrisome
successful = 131490/(192871+131490)
successful
# Out:
# 0.4053816580908309

# %%
# changing the target variable to 0 and 1 
df['state'] = df['state'].map({'failed':0, 'successful':1})
df['state'].value_counts()
# Out:
# 0    197719
# 1    133956
# Name: state, dtype: int64

# %% [markdown]
# # Deleting Nan values

# %%
df.dropna(axis=0, inplace=True)

# %%
total_nan = df.isna().sum().sort_values(ascending=False)
percentage_nan = (total_nan / df.shape[0]) * 100
tabel = pd.concat([total_nan, percentage_nan], axis=1, keys=['Total NAN', 'Percentage of NAN'])
tabel
# Out:
#                   Total NAN  Percentage of NAN
# usd_goal_real             0                0.0
# usd_pledged_real          0                0.0
# usd pledged               0                0.0
# country                   0                0.0
# backers                   0                0.0
# state                     0                0.0
# pledged                   0                0.0
# launched                  0                0.0
# goal                      0                0.0
# deadline                  0                0.0
# currency                  0                0.0
# main_category             0                0.0
# category                  0                0.0
# name                      0                0.0
# ID                        0                0.0

# %%
# Reseting the dataset 
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Using NLTK Library to tokenize
# - Tokenize the name column

# %%
# Instantiating
lemm = WordNetLemmatizer()
corpus=[]

for i in range(0, len(df['name'])):
#     print(i)
    doc = re.sub('[^a-zA-Z!?]', " ", df['name'][i])
    doc = doc.lower()
    doc = doc.split()
    doc = [lemm.lemmatize(word) for word in doc if not word in set(stopwords.words('english'))]
    doc = " ".join(doc)
    corpus.append(doc)

# %%
corpus
# Out:
# ['song adelaide abullah',
#  'greeting earth zgac art capsule et',
#  'hank?',
#  'toshicapital rekordz need help complete album',
#  'monarch espresso bar',
#  'support solar roasted coffee green energy! solarcoffee co',
#  'chaser strip strip make shot b tch!',
#  'jesus madman',
#  'lisa lim new cd!',
#  'cottage market',
#  'g spot place gamers connect eachother go pro!',
#  'tombstone old west tabletop game miniature mm',
#  'survival ring',
#  'beard',
#  'note london',
#  'mike corey darkness light album',
#  'boco tea',
#  'cmuk shoe take life foot first',
#  'mikeyj clothing brand fundraiser',
#  'alice wonderland g minor',
#  'mountain brew quest alcohol sustainability',
#  'book zoo mini comic',
#  'matt cavenaugh jenny power make st album!',
#  'superhero teddy bear',
#  'permaculture skill',
#  'rebel army origin heroic story major gripe',
#  'moon animated short film',
#  'daily brew coffee',
#  'ledr workbook one tough journal!',
#  'feather cast furled fly fishing leader',
#  'bb',
#  'chris eger band new nashville record!',
#  'squatch watcher',
#  'arrow sound debut album',
#  'zen america film zen buddhism north america',
#  'galaxy winnie friend',
#  'help scott reynolds make new record!',
#  'phil younger slow official music video',
#  'return book project',
#  'penny bingo playing card game fun whole family!',
#  'please please studio premiere',
#  'one street music new orleans',
#  'hot chicken take',
#  'star snowman',
#  'sea iron',
#  'visible empire tee',
#  'see dream narrative feature film',
#  'h underwater portrait',
#  'skateframes photo frame made recycled skateboard wood',
#  'teacher travel china',
#  'mother living fit yoga dvd mom baby',
#  'mobile barbecue catering trailer',
#  'following call novel',
#  'underwater',
#  'fanalyzers view stand',
#  'empire sea',
#  'teacher sky',
#  'fashion removeable decoration jewel accessory hell shoe',
#  'russia love simon',
#  'hiit bottle',
#  'jurassicjurassix guilt',
#  'safer home',
#  'pantochino production cinderella skeleton musical',
#  'shreddit privacy reddit',
#  'flying carpet azerbaijan iran turkey anatolia',
#  'diposta liberating people postal mailbox',
#  'future passed debut cd jazz trio',
#  'vote anyone trump candle',
#  'complicated ariana salome',
#  'secular solstice',
#  'uncommon rhythm season one',
#  'legacy svarog unique action rpg adventure game',
#  'anvil beard',
#  'awe antediluvian war extermination tactical card game',
#  'road shire',
#  'spiral electric skylab recording',
#  'local shirt',
#  'home? anthology',
#  'diet! thanks rather lose weight',
#  'onrust project two row treaty',
#  'coffee box',
#  'tu sabes? know? music collaboration daya edu',
#  'silence hollowind urban fantasy rpg',
#  'p v comic literary anthology',
#  'little shop horror browncoat theatre!',
#  'dark water project',
#  'los angeles international student film festival',
#  'bob contemplates ending',
#  'girl bathroom',
#  'best spray bottle ever sureshot',
#  'new lasagna',
#  'another reality show season',
#  'backroads ep processing cost',
#  'disaster area podcast',
#  'titanium edc bottle opener',
#  'eat like gilmore cookbook',
#  'bad example southern trailer park fairy tale indie short',
#  'patty party mumblecore horror feature',
#  'bold threadz',
#  'happy fix usa',
#  'part next smb project album',
#  'daytrader financial board game',
#  'irninja control tv simple press button',
#  'mama meatball',
#  'ebony child music artist drop new album comic book film',
#  'alpha omega e p',
#  'carriage',
#  'allthis tv',
#  'legendary yd tour',
#  'memory lane',
#  'jane brown story courage survival love',
#  'case lynk emergency iphone charge sync cord',
#  'cat pre professional ballerina',
#  'wordwright de fin ing word play',
#  'serino pizza rolling pizza lab food truck',
#  'photobook life japan',
#  'operation make stuff',
#  'xi help u usher post pc era',
#  'help wood shop buy lathe hopefully laser engraver',
#  'spirit asunder',
#  'store facade painting pittsburgh',
#  'trackside independent documentary featuring marshal',
#  'brandi emma promotes new song ep you! pre order right',
#  'gantish online reward chart creator parent',
#  'urbnpop chris hamer sketchbook',
#  'sellegg start classified site',
#  'farmer brown analogy farm game age three',
#  'seven ray',
#  'four short story ten love poem',
#  'david larocca star spawn',
#  'calendar cat',
#  'dogma short film',
#  'project u neek',
#  'architecture design website',
#  'notmypresident protest tee',
#  'musical light suit',
#  'gone second',
#  'ya science fiction comedy book series zeek kim lo',
#  'rising star unsigned artist compilation album',
#  'musical stage escenario musical',
#  'hydra dice',
#  'islamic world strategic gaming islamic value',
#  'hangar foundation',
#  'adele heart going edinburgh',
#  'odin android smart projector carry pocket',
#  'jenny photography start business travel!!',
#  'kaleidoscope man',
#  'operaci n douve',
#  'sketch',
#  'advent saga digital tactical card game',
#  'one man opinion moonlight song collection',
#  'crap amidst hilarity vol',
#  'packable fashionable protective ultimate sun hat',
#  'echo fuel make echo portable universal charging base!',
#  'voxcube x x rgb led chainable cube',
#  'new world disorder',
#  'generation fx documentary film',
#  'rack ruin orbit',
#  'help prepare upcoming art show',
#  'forever rechargeable talking super capacitor flashlight',
#  'covenant',
#  'elephant gun medium blitzkrieg',
#  'shared story afghan diary',
#  'gentle art tutelage',
#  'air bonsai create little star',
#  'canadian invasion choose adventure album',
#  'wrist cover',
#  'high stake short film',
#  'fomatek foam laptop desk music stand elevate gear',
#  'rising',
#  'sky scraper project',
#  'key moon first full length album!',
#  'worrisome wilf beastly bedtime',
#  'airfoil click pen aviation inspired gel rollerball',
#  'vlc new window user experience metro',
#  'raise fund new jonathangluck wayward kind album!',
#  'spider fly',
#  'knock drag',
#  'day dead tyrion lannister calavera vinyl sticker',
#  'harold v horde',
#  'camille peruto new album',
#  'app custom shoe calzado personalizado madame marian',
#  'tye photographic journey',
#  'ropw',
#  'chelsea chronicle podcast',
#  'wildlife inspired shirt help help wildlife',
#  'sword asumi visual novel',
#  'wax stack lp record crate',
#  'throw car door dent protector',
#  'strawberry field caf patisserie',
#  'tofu stylish shirt made freedom',
#  'american confines vol cincinnati',
#  'good company',
#  'launch romeo juliet yiddish new york city',
#  'case silent girl dark sherlock holmes tale',
#  'chasing blue trans theatre festival',
#  'mooli london designer camera tech bag hampton',
#  'clothing label state mind made france',
#  'ultimate custom shark rig',
#  'conference paradigm shift meeting',
#  'climbing kidz',
#  'tugboat collective inaugural season',
#  'geocaching trading card history series ii',
#  'fun n easy cookbook child well fun cooking',
#  'space trucker',
#  'high',
#  'club wick',
#  'modern handmade ceramic paper clay',
#  'join completing first solo project cd!',
#  'emotional makayla mommy birthday gift!',
#  'ashley beauty tool organizer kit',
#  'alaska bug bite llc farmer market launch',
#  'quick query relaunch!',
#  'quick clockwork knight volume',
#  'writtenwitheart',
#  'uptown juice company local cold pressed goodness',
#  'strain war playing card',
#  'wood floor fundraiser',
#  'water purification system using solar evacuated tube',
#  'steel cathedral short poem digital age',
#  'chameleon chronicle color fate',
#  'ghost ephemeral song ep',
#  'via chic oneclutch',
#  'afraid galileo album',
#  'paterson fall film festival',
#  'spilt milk',
#  'thailand country side',
#  'equinox first comic genre fantasy',
#  'student operated fabrication lab',
#  'nurse mare foal born die',
#  'bird nerd',
#  'funky grit fast casual diner pairing music menu!',
#  'great kentucky goblin spree',
#  'help put community building art austin patterson park',
#  'made scratch',
#  'pierced heart tattoo boutique start',
#  'pole diversity showcase acrobatic dance part two',
#  'mckenzie project',
#  'new omni wheel mechanical innovation created robot',
#  'brewstick carboy ruler',
#  'open fiesta art store dreaming big san antonio',
#  'opening portal dvd',
#  'night terror garden limbo',
#  'inclusive toolkit tool io o x app accessibility',
#  'greek fun',
#  'hood brewery',
#  'fooju dance collaborative',
#  'chris critelli record debut ep!',
#  'piero marsili',
#  'sleeping truck',
#  'design leatherjacket',
#  'sanfilippo wing it!',
#  'road runner multisport smartphone carrier',
#  'lego imagination lab',
#  'arkham source book',
#  'finishing festival fund final stage short film',
#  'lonely house film adam hope',
#  'adult colour debut album',
#  'open r',
#  'home maine film series homebirth midwife',
#  'fusionproject',
#  'lego batman zombie genesis series',
#  'digitizing family',
#  'progress steampunk series season',
#  'winter writing residency',
#  'dome shade sunglass big head',
#  'portrait day challenge',
#  'xpump turn sound source home theater experience',
#  'complete paine skatepark',
#  'westward',
#  'paperback kindle available get le here!',
#  'tiba putt personal approach improve putting',
#  'ghost herd rescuing horse horse people kentucky',
#  'gideon epic forge',
#  'survyval breakthrough hoodie',
#  'farmer bean holy roast',
#  'jessica rabbit production',
#  'final hours!!! kira kira rainbow unicorn stickers!',
#  'belleflower feature film',
#  'mab mindz sound set',
#  'lei',
#  'get back adaptation wrong becomes',
#  'bicycle bus',
#  'st cookbook child',
#  'book maxwell',
#  'glory three kingdom guandu core set',
#  'great apple pie',
#  'belongs world ackermann repository arts!',
#  'seven devil feature film',
#  'chill puck keep beverage colder longer',
#  'hero stranger fringenyc',
#  'project world',
#  'quadrato retractable knife make',
#  'single track contemporary art gallery espresso bar',
#  'great fly cup bake',
#  'un amour oublie love forgotten',
#  'loop resource strategy game tomorrow leader',
#  'contractor create model prop asset model',
#  'sasha fashion show spectacle',
#  'bass river press',
#  'betul soykan record joaquin turina violin work cd project',
#  'food truck world',
#  'publishing occupy portrait',
#  'daweyu hill crop cup',
#  'dream project',
#  'peripheral vision short film',
#  'pimax world first k vr headset',
#  'oakland',
#  'florida broken kingdom',
#  'help start jacksonville first paint pottery store',
#  'baby boom baby bag',
#  'euno',
#  'scar tissue',
#  'stagnant pool enters post production',
#  'pro movement',
#  'billion dollar project',
#  'novel',
#  'peak view brewing company',
#  'finding black love documentary',
#  'patch organic',
#  'virtual addiction recovery website phone app saving life',
#  'fatnek clothing sublimation series shirt',
#  'titanium whiskey glass epic drinking glass',
#  'child feature length comedy',
#  'college spring break review',
#  'tall tale evening dance choreojoey',
#  'light come',
#  'wood fired oven growing community',
#  'trap nd record vinyl release',
#  'rocky horror saved life fan documentary',
#  'song damned jake brock latest album',
#  'circa vitae request crowd fundage record full length album vinyl!!!',
#  'stiletto red new ep',
#  'buck county movie',
#  'lazershirts! another shirt',
#  'country christian album titled believe',
#  'color art party',
#  'wholesters new way whold things!',
#  'stamped',
#  'steer wearable device save life',
#  'ripple analysis bringing animation life',
#  'croc pop kid manage dad digital addiction',
#  'carolina hottest',
#  'tulip',
#  'ignis fatuus comic project',
#  'hoodratz',
#  'kingdom space exploration rpg',
#  'leonard hodgins component',
#  'deluxe rpg handbrain screen',
#  'la press make soap home minute chemicals!',
#  'c r w n help u finish feature film',
#  'spicing whipped beaten culinary work',
#  'grilling beer cookbook',
#  'womanhood short film fundraiser',
#  'sunrise diary',
#  'tommy',
#  'first solo exhibition recognised gallery next step up!',
#  'bromotion',
#  'film project history coming',
#  'savage thunderscape!',
#  'mc type bad tattoo vol',
#  'man island',
#  'completion history kent',
#  'grandkids record full length album!',
#  'border',
#  'firewater',
#  'annulus ring light',
#  'gospel jazz independant artist cd project',
#  'ugly cartoon poorly drawn miserable people!',
#  'occupy left forum zine',
#  'dancing classroom grva',
#  'daily bread story rural greece',
#  'monster short film christina morris',
#  'black knight brick built bbq grill',
#  'boating clyde adventure puget sound',
#  'beyond victory recording debut ep',
#  'daystay',
#  'league honor',
#  'making bringpacks',
#  'projecteo tiny instagram projector',
#  'digital aristocracy commoner guide digital rich',
#  'time move',
#  'lazy glamour eco underwear soft sustainable u made',
#  'saber design apparel',
#  'capturing soul town',
#  'soft organic cotton underwear give back',
#  'storybox make today?',
#  'cyberines',
#  'poem apostate tale young scientologist',
#  'screening mr turner',
#  'senior project short film home',
#  'treasure trapped',
#  'suburban daze',
#  'flyover farm',
#  'focus fan lion tour',
#  'zero dark thirty watch make difference',
#  'baby name name newborn',
#  'faithful lesbian mormon story',
#  'lazer edge series ebike starting !',
#  'intelishake smart sport drink bottle built storage',
#  'bailey golden retriever calendar',
#  'painting portraits! custom painting',
#  'spun monkey dyeworks lounge',
#  'reusable giant coloring poster black',
#  'lux wellness lamp',
#  'living puppet novel',
#  'romantic christmas',
#  'project earth call u monster story bias',
#  'yemanja caribbean restaurant bar hostel',
#  'eucalyptus wear environmental clothing company',
#  'jazz funeral coney island',
#  'self illusion best friend worst enemy ep',
#  'blak woman dynamik reborn',
#  'cause art gallery',
#  'thailandmike portfolio hiccup tour guide sketchbook',
#  'midwest side story',
#  'pentimento documentary rene gimpel',
#  'mike moreno group fall release',
#  'sansin band ep',
#  'tale sheepland imagination child',
#  'kindness stranger',
#  'maybe poison',
#  'smart dive buddy smartphone dive camera computer',
#  'final fantasy viii happened next?',
#  'iphone skin made real apple wood',
#  'goalzidia let reach goal together',
#  'mongol art world tour save art',
#  'darling june',
#  'monster mob fun card game monster family',
#  'blacklivesmatter series',
#  'sorensen glass studio',
#  'free supercomputer',
#  'king astronaut documentary',
#  'music fame diva dj shirt',
#  'mp dance amiti perry company',
#  'flutter flow knitting book',
#  'sci fi janitor v redbull soapbox race',
#  'redemption',
#  'course make stunning fantasy rpg gamemaker studio',
#  'secret behavior magazine',
#  'michale graf vagabond acoustic extremely limited edition',
#  'odyssey skateboard launch',
#  'poolpooj',
#  'dark forest',
#  'shoot thrill shoot kill? political sculpture',
#  'structure',
#  'money shot',
#  'vagabond search homeless father',
#  'earthreads fabric future',
#  'no! game quick move stolen turn',
#  'amateur prose book poetry story original art',
#  'little boy wonder short film',
#  'judged irreverent party game',
#  'starting herb garden',
#  'phantom limbed romantic comedy',
#  'defender realm minion',
#  'matt whistler movie feature film',
#  'undoing trilogy',
#  'guardian salus book halix series',
#  'blake burger',
#  'build traditional tipi',
#  'legend white woman creek',
#  'develop new world hottest chilli',
#  'rock audition concert sheri sander',
#  'fragile stephanie mathias first ep!',
#  'second scene culture city project',
#  'agrandissement de la brasserie',
#  'go far christopher rush story',
#  'esquilo simple iot development wifi web ide cloud',
#  'bone cherry hog',
#  'random table wiki',
#  'natural face foot body scrub',
#  'lds home teaching app visiting teaching',
#  'mother going',
#  'fritz robotic puppet',
#  'casper bad spirit lp funding',
#  'minecraft hungergames',
#  'world fair',
#  'campbell glasswork co',
#  'zen tek aquaponics run air',
#  'poem',
#  'burning manc festival',
#  'airlock bike helmet',
#  'lampenschirme und objekte au franz sischer handarbeit',
#  'wood',
#  'green lizzie container truly adapted recycling',
#  'better morrissey birthday mix',
#  'ride suicide',
#  'mm aluminum pick plectrum',
#  'tara normal',
#  'photoshop illustrator designer',
#  'profound fatigue produced flying deer theater revised',
#  'dungeon hero',
#  'turn messy arduino project clean design',
#  'painting entire favela rio de janeiro',
#  'open tank',
#  'reed bringing tablet reading speed',
#  'flag world',
#  'mover kit get kid moving building coding',
#  'volksdangler hack pocket',
#  'p link guitar pickup interchange system',
#  'book bare bone',
#  'profitstick feel power',
#  'mailbox forthcoming album!',
#  'rocket ranger reloaded',
#  'write estimate estimate written anywhere!',
#  'portscenter',
#  'like neighborhood',
#  'sparklab educational build mobile!',
#  'karma get face lift!',
#  'restaurant going grain colchester essex',
#  'bull dragon pop restaurant project',
#  'may torque',
#  'stage one stage two music theatre',
#  'phochron xa film camera shutter speed tester',
#  'vivian dog move brooklyn',
#  'darkghost assignment book brother',
#  'mick life',
#  'free soap starting soap maker!',
#  'nice set shell handmade seashell jewelry',
#  'shattered restored',
#  'barry county milk',
#  'giant communist',
#  'surf right documentary inspired cold water surfer',
#  'survive treasure island choose path',
#  'talega holiday annual halloween light show!',
#  'help publish picture kid books!',
#  'moon eye view save world',
#  'safe food makeup household products?',
#  'geek seeker',
#  'quern undying thought',
#  'nabil karim anise k bicentenary album',
#  'destroy slacker animated feature film',
#  'seeker aerial video drone',
#  'quikceipt! paperless solution',
#  'splendid entity catalog project',
#  'champion child vol known champ fund',
#  'dragonfly',
#  'ale house string band debut album',
#  'new cornell hurd band cd great new song love!',
#  'dodecahedrone rpg post apocalyptic robot',
#  'follow help u get barney',
#  'da dome roller skating rink brooklyn new york',
#  'tankwork cooperative tank action',
#  'winter mind ep funding',
#  'day commision spree ! get custom hand drawn art!',
#  'charlene kaye make new record animal love',
#  'top chef opening shakewell bar kitchen!',
#  'lonely himalaya',
#  'phrenic interactive comic alternate reality game',
#  'carnival art exhibit miami international airport',
#  'unassisted ep revolution',
#  'dead night',
#  'wazupio',
#  'daggermond',
#  'choose fate film put charge',
#  'lock jean',
#  'do pueblo tecnicos',
#  'geekholder hold phone tablet laptop screen',
#  'maze slime',
#  'long range murs band gps tracker smartphone communicator',
#  'sin roleplaying game',
#  'cakehouse layer studio comic zine',
#  'shirt protest trump putin connection',
#  'doctor menace foonf',
#  'bird eye view map atlanta piece puzzle',
#  'prelude conversation',
#  'new social network',
#  'autopsy dying man',
#  'art lover place',
#  'bona dea gluten free goodness',
#  'got beat fbi four year old',
#  'pony death ride making album!',
#  'love animal debut ep project',
#  'unknown arizona',
#  'bridge sigh short film part',
#  'legendary steamboat spring band record album years!',
#  'luxury timepiece system minimal everyday watch system',
#  'rest stop restaurant',
#  'maree v state documentary',
#  'girdy! webcomic',
#  'magic tower',
#  'da stooge wipeout surfaris',
#  'lobster art project',
#  'quartz bottle water purification self cleaning bottle',
#  'following racine east africa safari rally',
#  'sky lounge visual ep',
#  'acnedust organic acne treatment acne dust sleep powder',
#  'legendary cobo',
#  'philip brittany burton new album nothing fear',
#  'mason ry silicone koozie',
#  'shirt east idaho aquarium',
#  'new lp release shape earth',
#  'rinsekit revolutionary portable shower',
#  'singularity',
#  'taluva deluxe version',
#  'calvin thomas making october sky album!',
#  'wilmer wilson iv summer art residency nls',
#  'gladys sings',
#  'lake george music festival',
#  'seeking shelter vol rescue animal ho!',
#  'boutique disco flash qu bec',
#  'fail safe project first full length album',
#  'door feature film finishing fund',
#  'decorative oxygen tank bag amarijade inc',
#  'commit suicide',
#  'scarf cuff',
#  'behold uprising ep',
#  'johnny strange',
#  'panini company',
#  'legendary warrior production',
#  'statue doc u marine corpsman!',
#  'stagecoach mary',
#  'knot app',
#  'powerbark meal run dog go',
#  'tenacious exclusive scott tolleson uncle argh noir mini qee',
#  'centennial armenian genocide shirt',
#  'mini flashlight fire starter',
#  'bigger inside',
#  'jordon bould butcher block',
#  'alone',
#  'somo mixtape',
#  'little woman graphic novel project',
#  'joy ike recording rd full length album! let it!',
#  'lotus earring',
#  'adult',
#  'bohemian book project',
#  'viking hood alive kicking!',
#  'tenor journey german land',
#  'vanilley bean treats! life sweet moments!',
#  'wheeling careening wandering emp',
#  'fireball newsflash crossword',
#  'kung fu bellydance master ????????',
#  'academia de sica impulsarte org',
#  'one world one year',
#  'living coaster beverage coaster grows plants!',
#  'naturalia young adult book! surprise girlfriend',
#  'chop sooey charm pin',
#  'wheelhouse farm table restaurant st joseph il',
#  'galaxy trian new order',
#  'air air! portable air quality detector',
#  'conduit sport dynamic bone conducting headphone',
#  'one',
#  'tableau vivant delirium construction global tour',
#  'seth pineapple mango salsa',
#  'day x',
#  'one day time day photograph',
#  'free world brand clothing co',
#  'planet hell post apocalyptic web series',
#  'little falcon need help!',
#  'customizable printed miniature',
#  'short defender',
#  'heya toothbrush holder simple clean keep bacteria away!',
#  'imminent',
#  'love tongue death eye',
#  'pocket parking meter',
#  'mechabrick minifig mecha board game model',
#  'cat cafe mad coffee shop remodel expansion real food',
#  'pollock l acchiappa panzane',
#  'unconditional hope survivor story',
#  'finishing amish appeal',
#  'gamerline clothing starter business need help!!',
#  'sport city',
#  'vyu k procam',
#  'justifier',
#  'sinner iii supernatural horror comic night motel',
#  'ez master double boiler attachment stand mixer',
#  'shakespeare!! fund fund question?',
#  'monkey paw',
#  'charlie v goliath',
#  'new madysin hatter ep titled pretty little fool',
#  'release black heart album',
#  'bad day blue',
#  'pappino dein foto auf einem recyceltem kartonrahmen',
#  'coach life time shawn tompkins',
#  'life online',
#  'promise tempus film',
#  'grace gentle playing card lunzi',
#  'kingdom angelic war card game',
#  'april alayne studio',
#  'ultra way cool teaching puppet',
#  'chain mail creation',
#  'film perfect divorce',
#  'average grilled cheese',
#  'supplicant age dissidence',
#  'diarios de viaje pel cula',
#  'al garza h r core!!!',
#  'kind mind wise soul launch next collection!!!',
#  'bring seattle geekly podcast back!',
#  'galactic princess',
#  'la feria concreta documentary film installation',
#  'debut original album mindy stratton',
#  'night rider',
#  'xybears last hero',
#  'archive warhood odyssey',
#  'vaudezilla! chicago burlesque coloring book matt hansel',
#  'homestyle video installation delicious spectacle',
#  'color press th street garment company',
#  'maltese brewing company',
#  'hollow',
#  'perfect plan',
#  'dionysius game indy game everyone',
#  'music production',
#  'markus mann music cd production tour',
#  'tropical bat house',
#  'wade water gallery',
#  'woodland banner poetry walk',
#  'soul take nd ep record',
#  'home jug decal shirt trophy tailgate',
#  'battle orion',
#  'pretty ugly awp',
#  'homebound film transforming image latino',
#  'nepenthe short film',
#  'jesus homeless woman clay bronze',
#  'audio heroin chic cyber doll',
#  'self produce debut album',
#  'bizarre case globular gullet',
#  'earth wall ii rammed earth sculpture',
#  'two boy bow tie tour',
#  'inch short film',
#  'teslatronix tesla power mass',
#  'wood gift make personal memory',
#  'inspire x sound',
#  'pastor damien season one',
#  'speculative relationship sci fi romance comic anthology',
#  'veteran art david geig',
#  'marketplace crowdfunded product',
#  'note self',
#  'orillia summer theatre',
#  'maria sweet sings!',
#  'aurora chronicle hero',
#  'aj handmade style',
#  'kickstart art',
#  'paladin warrior charlemagne',
#  'john lennon give peace chance book',
#  'jessica jewelry',
#  'creative community',
#  'green light radio broadcast arise festival',
#  'poetry safe new best reading ever film',
#  'man day canvas',
#  'bt block tower',
#  'versa tool',
#  'dreamafrica',
#  'failure jacket',
#  'dayz come new worship project',
#  'healthy sustainable clothing',
#  'new york travel sightseeing video blog',
#  'magpi magazine virtual reality',
#  'loquat could arsonist short film music video',
#  'unique collage',
#  'corey coffee bar',
#  'inhale sunrise',
#  'son odin fantasy football',
#  'chimera station euro edition',
#  'ghetto love written weedie',
#  'ping attack sphere wii u p steam',
#  'loud bicycle car horn bike',
#  'vince durden world eco friendly backpack',
#  'mile',
#  'black mint playing card',
#  'holiday experience jazzy christmas celebration',
#  'renwick ally album ryan angell aka andrew juco',
#  'amphibious red couch',
#  'rabbitwild shelter wilderness',
#  'leah stein dance company th anniversary concert',
#  'parthia saffron door one thread time!',
#  'upcycled planter',
#  'youth education tv talk show',
#  'mango pineapple habanero toe curling hot lava sauce',
#  'epic backpacking dynasty global millennial revolution',
#  'ainsley band uk tour',
#  'fantuckfastic onesies',
#  'iwish sigil magic',
#  'mar transit game funspace circle friend bo regard',
#  'self sufficient water filtration system first kind!',
#  'sawyer dinosaur child book',
#  'magician cat print edition ebook!',
#  'berwyn project ep mc type thewoods',
#  'undive dark sea',
#  'iviou future buying selling online',
#  'rustic reclaimed furniture hand made',
#  'lonesome day st studio album!',
#  'league legend cosplay',
#  'lose like human',
#  'animal playing card',
#  'entertain u photobook lois golding',
#  'seeing swiss picture people world engineering',
#  'love gut high school',
#  'cafe gangster',
#  'river monroe fall tour',
#  'golf alpha yankee lgbt human right documentary',
#  'colombian art gallery la magic realism strike back!',
#  'turn back',
#  'ten animal mask week',
#  'dancer descended mount kenya memoir',
#  'press start bar',
#  'zombme',
#  'shirt design startup',
#  'zisil',
#  'faceless neil',
#  'starbird land earth debut album time',
#  'bryan wilton print audio',
#  'downtown mural',
#  'zombie usb keychain zed',
#  'skullgarden linocut print project',
#  'soundtrack story dj',
#  'give sweet surrender',
#  'alaina blair cd tour project',
#  'cemetery angel photographic book',
#  'sledge leather reply insert large as metal label',
#  'kensaku shinohara mana spring',
#  'help exhibit art show geordanna artist',
#  'exoskeleton assault squad hura technocracy mm sci fi',
#  'moar online multiplayer fighting game',
#  'esperanza gang intervention photo documentary',
#  'jakten p makten br dspelet om svensk politik',
#  'create liberal america',
#  'cooking fire disaster cookbook',
#  'violet tendency starring mindy cohn dvd',
#  'disgruntled deck original card game veteran',
#  'come sea ambitious short film',
#  'elemental burning city',
#  'sol mcnally photography',
#  'led packlight let bend light need',
#  'flowpaw learn computer coding building gizmo',
#  'home ground',
#  'pixel press draw video game',
#  'sexy action accounting myth short film',
#  'moment make iphone better camera',
#  'poetry never',
#  'post election student voice hope resistance',
#  'ion music detecting mood light bluetooth low energy',
#  'bringing patrizi back family food truck experience',
#  'musical help trouble number one many',
#  'fused defiance album',
#  'go mobile drool central',
#  'awfully sudden album',
#  'beyond parallel print edition run coming age novel',
#  'want apply x factor music project',
#  'beaten track',
#  'lover lost feature film',
#  'coon age volume one',
#  'might well live dorothy parker hollywood fringe',
#  'traditional astrophotography window cygnus',
#  'hole wall hector record debut studio album!',
#  'lighten',
#  'surrender spirit creative writing project phase',
#  'newton wildlife adventure',
#  'secret tomato project',
#  'xstink',
#  'opening online gallery great dinosaur art artist',
#  'meditation simple technique beginner',
#  'qi aerista ultimate wi fi enabled smart tea maker',
#  'art mitch foust yearbook',
#  'bring victorian life',
#  'chat choice gaming',
#  'thank letter krys',
#  'margoh! make legend drink more? london style',
#  'original painting',
#  'opuntia',
#  'debut hip hop album mikelwj',
#  'shattered shard printable fantasy war game scenery',
#  'temple flower vibrant activewear yoga apparel',
#  'scorned starring american idol alum x grammy nominee chip',
#  'project',
#  'maori mbt awareness centre',
#  'weekly video series',
#  'bike pouch',
#  'global intersection world material method',
#  'zombie shirt hoodies',
#  'alwaysremembered com new way remember loved one',
#  'moustache bow tie project mo bros mo sistas',
#  'first official music video single forever',
#  'prelude psychological survival horror game',
#  'bible app',
#  'een leven lang flow',
#  'garment collective ethically sourced redemptively made',
#  'beginning mark barnes',
#  'challis effect heart built graveyard',
#  'log',
#  'maui maine claybourne tour',
#  'world adventure fantasy realm',
#  'perfect boot fernando berlin',
#  'dihydrogen monoxide conspiracy',
#  'survival kit',
#  'ton music buck!!!',
#  'adoree european promo tour summer',
#  'read bible year card system',
#  'rob wiley custom leatherwork',
#  'n love official launch',
#  'littlerp affordable flexible open resin printer',
#  'fallen guardian angel film project',
#  'monocrane reversible leather book bag photochromic ink',
#  'hilarious film called mooo',
#  'hi! please help publish wizard legacy !',
#  'bondurant brother distillery',
#  'summer goth finishing fund',
#  'without',
#  'duo diy twin lens reflex camera instant film',
#  'western sydney art academy',
#  'pursu passion career',
#  'crazy train',
#  'railway mania eastern county',
#  'life see',
#  'pongcaddie save ball beer pong net',
#  'julia fanning debut ep',
#  'sprite lamp dynamic lighting art',
#  'z day lena pendleton',
#  'road italy!',
#  'immersive cinema',
#  'bbq dragon barbecue fire supercharger!',
#  'dineamics',
#  'unearthing',
#  'uncle samta final hour',
#  'know like',
#  'igloo glass world coolest beer glass',
#  'treasure book cover',
#  'came sweat',
#  'finish el toro tot food trailer!!',
#  'madjacks ski pain free walk normally affordably',
#  'phil king leeland',
#  'elbow knee crippled crush ep',
#  'broadway come denver scholarship fund',
#  'bedroom behavior lingerie',
#  'love libya',
#  'amazing tale wasted land inaugural issue pre sale!',
#  'geex season one!',
#  'old soul lion',
#  'sleep board',
#  'kevin woody first solo album',
#  'norman einstein normanthology',
#  'please donate money first music video shooting september',
#  'kronos pino family ranch',
#  'stolen crystal',
#  'low shoulder short film',
#  'endless whisper cycle featurettes',
#  'dexter etsy shop expansion',
#  'inflatable jake band shirt',
#  'artisan vinegar',
#  'saga splintered realm',
#  'make coolrunnings first physical release reality',
#  'st studio unplugged wood headphone featuring bluetooth',
#  'film',
#  'edgar wallace jr get saxy studio new c',
#  'cirsova lovecraft sword space ships!',
#  'lego chess set',
#  'feeding finger first double album',
#  'telemetry webisodes',
#  'song without word',
#  'chris custom built pc',
#  'make record ben cyllus part new project',
#  'still motion present moment defined nyc',
#  'letter basic training',
#  'major factor',
#  'watch inspires life',
#  'affordable computer controlled quilting system add',
#  'manboy lp oliver manning',
#  'red box get privacy back cloud',
#  'odyssey homer amazing youth actor giant puppets!',
#  'namm marketing keeping big dog',
#  'debut ep album promotion',
#  'doodle creatively interactive child book',
#  'ninjutsu pencil holder',
#  'bocusini world first plug play food printing system',
#  'conservative theatre festival columbus oh',
#  'spread love',
#  'run fast',
#  'aivot',
#  'fashionrider show tell video documentary',
#  'shred pro rider snowboard game',
#  'riddle sphinx',
#  'weekend love',
#  'los angeles woman theatre festival th anniversary!',
#  'gender neutral pair dance exploring gender role dance',
#  'illusion reality',
#  'daniel ordinary tragedy new musical',
#  'glass paradise',
#  'genesis collection',
#  'attention life extreme',
#  'covalence molecule building game',
#  'professor vogel alternative history machine issue iii',
#  'monadnock gymnastics',
#  'banaau getting next level',
#  'solo art show miami',
#  'cinema verde',
#  'dousing sauce story',
#  'king guild',
#  'nostalgic restoration youth',
#  'beast spearpointe book new epic fantasy series',
#  'napa valley private label wine',
#  'human wanted sf anthology',
#  'ian mahan new album little moment',
#  'gb detroit present daniel harrison highway',
#  'pot coffee',
#  'pet bed',
#  'paprika short film',
#  'darker shade fado',
#  'life career changing dream camera goal!',
#  'lightbulb terrarium hand made mini terrarium',
#  'dead burger abomination films!',
#  ...]

# %% [markdown]
# # Using Spacy Library to tokenize

# %%
# instantiate the spacy object 
nlp = spacy.load("en_core_web_lg")

# %%
tokens=[]

for doc in nlp.pipe(df['name']):
    
    doc_tokens = []
    
    for token in doc:
        
        if (token.is_stop == False) & (token.is_punct ==False) & (token.pos_ != 'PRON'):
            doc_tokens.append(token.lemma_.lower())
            
    tokens.append(doc_tokens)

# %%
# Now we need to extract list from a list 
tokens
# Out:
# [['songs', 'adelaide', 'abullah'],
#  ['greet', 'earth', 'zgac', 'arts', 'capsule', 'et'],
#  ['hank'],
#  ['toshicapital', 'rekordz', 'need', 'help', 'complete', 'album'],
#  ['monarch', 'espresso', 'bar'],
#  ['support',
#   'solar',
#   'roasted',
#   'coffee',
#   'green',
#   'energy',
#   ' ',
#   'solarcoffee.co'],
#  ['chaser', 'strips', 'strips', 'shot', 'b*tch'],
#  ['jesus', 'madmen'],
#  ['lisa', 'lim', 'new', 'cd'],
#  ['cottage', 'market'],
#  ['g', 'spot', 'place', 'gamer', 'connect', 'eachother', 'pro'],
#  ['tombstone', 'old', 'west', 'tabletop', 'game', 'miniature', '32', 'mm'],
#  ['survival', 'rings'],
#  ['beard'],
#  ['note', 'london'],
#  ['mike', 'corey', 'darkness', 'light', 'album'],
#  ['boco', 'tea'],
#  ['cmuk', 'shoe', 'life', 'feet'],
#  ['mikeyj', 'clothing', 'brand', 'fundraiser'],
#  ['alice', 'wonderland', 'g', 'minor'],
#  ['mountain', 'brew', 'quest', 'alcohol', 'sustainability'],
#  ['book', 'zoo', 'mini', 'comic'],
#  ['matt', 'cavenaugh', 'jenny', 'powers', '1st', 'album'],
#  ['superhero', 'teddy', 'bear'],
#  ['permaculture', 'skill'],
#  ['rebel', 'army', 'origins', 'heroic', 'story', 'major', 'gripe'],
#  ['moon', 'animated', 'short', 'film'],
#  ['daily', 'brew', 'coffee'],
#  ['ledr', 'workbook', 'tough', 'journal'],
#  ['feather', 'cast', 'furled', 'fly', 'fishing', 'leader'],
#  ['bb130a'],
#  ['chris', 'eger', 'band', 'new', 'nashville', 'record'],
#  ['squatch', 'watchers'],
#  ['arrows', 'sound', 'debut', 'album'],
#  ['zen', 'america', 'film', 'zen', 'buddhism', 'north', 'america'],
#  ['galaxy', 'winnie', 'friends'],
#  ['help', 'scott', 'reynolds', 'new', 'record'],
#  ['phil', 'younger', 'slow', 'official', 'music', 'video'],
#  ['return', 'book', 'project'],
#  ['penny', 'bingo', 'playing', 'card', 'game', 'fun', 'family'],
#  ['studio', 'premiere'],
#  ['street', 'music', 'new', 'orleans'],
#  ['hot', 'chicken', 'take'],
#  ['star', 'snowman'],
#  ['seas', 'iron'],
#  ['in)visible', 'empire', 'tees'],
#  ["i'll", 'dreams', 'narrative', 'feature', 'film'],
#  ['h2o', 'underwater', 'portrait'],
#  ['skateframes', 'photo', 'frame', 'recycle', 'skateboard', 'wood'],
#  ['teacher', 'travels', 'china'],
#  ['mother', 'live', 'fit', 'yoga', 'dvd', 'mom', 'baby'],
#  ['mobile', 'barbecue', 'catering', 'trailer'],
#  ['follow', 'novel'],
#  ['underwater'],
#  ['fanalyzers', 'view', 'stand'],
#  ['empire', 'sea'],
#  ['teacher', 'sky'],
#  ['fashion',
#   'removeable',
#   'decoration',
#   'jewel',
#   'accessory',
#   'hells',
#   'shoe'],
#  ['russia', 'love', 'simon'],
#  ['hiit', 'bottle', '™'],
#  ['jurassicjurassix', 'guilt'],
#  ['safe', 'home'],
#  ['pantochino', 'productions', 'cinderella', 'skeleton', 'musical'],
#  ['shreddit', 'privacy', 'reddit'],
#  ['fly', 'carpets', 'azerbaijan', 'iran', 'turkey', 'anatolia'],
#  ['diposta', 'liberate', 'people', 'postal', 'mailbox'],
#  ['future', 'pass', 'debut', 'cd', 'jazz', 'trio'],
#  ['vote', 'trump', 'candle'],
#  ['complicate', 'ariana', 'salome'],
#  ['secular', 'solstice', '2014'],
#  ['uncommon', 'rhythm', 'season'],
#  ['legacy',
#   'svarog',
#   '|',
#   'unique',
#   '3d',
#   'action',
#   'rpg',
#   'adventure',
#   'game'],
#  ['anvil', 'beard'],
#  ['awe', 'antediluvian', 'war', 'extermination', 'tactical', 'card', 'game'],
#  ['road', 'shire'],
#  ['spiral', 'electric', 'skylab', 'recording'],
#  ['local', 'shirt'],
#  ['home', 'anthology'],
#  ['diet', 'thank', 'lose', 'weight'],
#  ['onrust', 'project', 'row', 'treaty', '1613'],
#  ['coffee', 'box'],
#  ['tu', 'sabes', 'know', 'music', 'collaboration', 'daya', 'edu'],
#  ['silence', 'hollowind', 'urban', 'fantasy', 'rpg'],
#  ['p', 'o', 'v', 'comic', 'literary', 'anthology'],
#  ['little', 'shop', 'horrors', 'browncoat', 'theatre'],
#  ['dark', 'waters', 'project'],
#  ['los', 'angeles', 'international', 'student', 'film', 'festival'],
#  ['bob', 'contemplate', 'end'],
#  ['girl', 'bathroom'],
#  ['good', 'spray', 'bottle', 'sureshot'],
#  ['new', 'lasagna'],
#  ['reality', 'season', '3'],
#  ['backroad', 'ep', 'processing', 'cost'],
#  ['disaster', 'area', 'podcast'],
#  ['titanium', 'edc', 'bottle', 'opener'],
#  ['eat', 'like', 'gilmore', 'cookbook'],
#  ['bad',
#   'example',
#   'southern',
#   'trailer',
#   'park',
#   'fairy',
#   'tale',
#   'indie',
#   'short'],
#  ['patty', 'party', 'mumblecore', 'horror', 'feature'],
#  ['bold', 'threadz'],
#  ['happy', 'fix', 'usa'],
#  ['smb', 'project', 'album'],
#  ['daytrader', 'financial', 'board', 'game'],
#  ['irninja', 'control', 'tv', 'simple', 'press', 'button'],
#  ['mama', 'meatballs'],
#  ['ebony',
#   'child',
#   'music',
#   'artist',
#   'drop',
#   'new',
#   'album',
#   'comic',
#   'book',
#   'film'],
#  ['alpha', 'omega', 'e.p.'],
#  ['carriage'],
#  ['allthis', 'tv'],
#  ['legendary', 'yd', '2016', 'tour'],
#  ['memory', 'lane', ' '],
#  ['jane', 'brown', 'story', 'courage', 'survival', 'love'],
#  ['case', 'lynk', 'emergency', 'iphone', 'charge', 'sync', 'cord'],
#  ['cat', 'pre', 'professional', 'ballerina'],
#  ['wordwright', 're·de·fin·e', 'word', 'play'],
#  ['serino', 'pizza', 'rolling', 'pizza', 'lab', 'food', 'truck'],
#  ['photobook', 'life', 'japan'],
#  ['operation', 'stuff'],
#  ['xi3', 'help', 'usher', 'post', 'pc', 'era'],
#  ['help', 'wood', 'shop', 'buy', 'lathe', 'hopefully', 'laser', 'engraver'],
#  ['spirit', 'asunder'],
#  ['store', 'facades', 'paintings', 'pittsburgh'],
#  ['trackside', 'independent', 'documentary', 'feature', 'marshal'],
#  ['brandi',
#   'emma',
#   'promote',
#   'new',
#   '5-song',
#   'ep',
#   ' ',
#   'pre',
#   'order',
#   'right'],
#  ['gantish', 'online', 'reward', 'chart', 'creator', 'parent'],
#  ['urbnpop', 'chris', 'hamer', 'sketchbook'],
#  ['sellegg', 'start', 'classified', 'site'],
#  ['farmer', 'brown', 'analogy', 'farm', 'game', 'age'],
#  ['seven', 'rays'],
#  ['short', 'stories', 'love', 'poems'],
#  ['david', 'larocca', 'star', 'spawn'],
#  ['calendar', 'cat'],
#  ['dogma', 'short', 'film'],
#  ['project', 'u', 'neek'],
#  ['architecture', 'design', 'website'],
#  ['notmypresident', 'protest', 'tee'],
#  ['musical', 'light', 'suit'],
#  ['go', '61', 'second'],
#  ['ya', 'science', 'fiction', 'comedy', 'book', 'series', 'zeek', "kim'lo"],
#  ['rise', 'star', 'unsigned', 'artist', 'compilation', 'album'],
#  ['musical', 'stage', 'escenario', 'musical'],
#  ['hydra', 'dice'],
#  ['islamic', 'world', 'strategic', 'gaming', 'islamic', 'value'],
#  ['hangar', '1', 'foundation'],
#  ['adele', 'heart', 'go', 'edinburgh'],
#  ['odin', 'android', 'smart', 'projector', 'carry', 'pocket'],
#  ['jenny', 'photography', 'start', 'business', 'travel'],
#  ['kaleidoscope', 'man'],
#  ['operación', 'douve'],
#  ['42', 'sketch', '2013'],
#  ['advent', 'saga', 'digital', 'tactical', 'card', 'game'],
#  ['man', 'opinion', 'moonlight', 'song', 'collection'],
#  ['crap', 'amidst', 'hilarity', 'vol', '1'],
#  ['packable', 'fashionable', 'protective', 'ultimate', 'sun', 'hat'],
#  ['echo', 'fuel', 'echo', 'portable', 'universal', 'charging', 'base'],
#  ['voxcube', '8x8x8', 'rgb', 'led', 'chainable', 'cube'],
#  ['new', 'world', 'disorder'],
#  ['generation', 'fx', 'documentary', 'film'],
#  ['rack', 'ruin', 'orbit', '3'],
#  ['help', 'prepare', 'upcoming', 'art'],
#  ['forever', 'rechargeable', 'talk', 'super', 'capacitor', 'flashlight'],
#  ['covenant'],
#  ['elephant', 'gun', 'medium', 'blitzkrieg'],
#  ['shared', 'story', 'afghan', 'diary'],
#  ['gentle', 'art', 'tutelage'],
#  ['air', 'bonsai', '|', 'create', 'little', 'star'],
#  ['canadian', 'invasion', 'choose', 'adventure', 'album'],
#  ['wrist', 'cover'],
#  ['high', 'stake', 'short', 'film'],
#  ['fomatek', 'foam', 'laptop', 'desks', 'music', 'stand', 'elevate', 'gear'],
#  ['100', 'rising'],
#  ['sky', 'scraper', 'project'],
#  ['key', 'moon', 'length', 'album'],
#  ['worrisome', 'wilf', 'beastly', 'bedtime'],
#  ['airfoil', 'click', 'pen', 'aviation', 'inspired', 'gel', 'rollerball'],
#  ['vlc', 'new', 'windows', '8', 'user', 'experience', 'metro'],
#  ['raise', 'fund', 'new', 'jonathangluck', 'wayward', 'kind', 'album'],
#  ['spider', 'fly'],
#  ['knock', 'drag'],
#  ['day', 'dead', 'tyrion', 'lannister', 'calavera', 'vinyl', 'sticker'],
#  ['harold', 'vs', 'horde'],
#  ['camille', 'peruto', 'new', 'album'],
#  ['app', 'custom', 'shoes/', 'calzado', 'personalizado', 'madame', 'marian'],
#  ['tye', 'photographic', 'journey'],
#  ['ropw'],
#  ['chelsea', 'chronicle', 'podcast'],
#  ['wildlife', 'inspired', 't', 'shirts', 'help', 'help', 'wildlife'],
#  ['sword', 'asumi', 'visual', 'novel'],
#  ['wax', 'stacks', 'lp', 'record', 'crate'],
#  ['throw', 'car', 'door', 'dent', 'protector'],
#  ['strawberry', 'fields', 'café', 'patisserie'],
#  ['tofu', 'stylish', 't', 'shirts', 'freedom'],
#  ['american', 'confines', 'vol', '1', 'cincinnati', '52'],
#  ['good', 'company'],
#  ['launch', 'romeo', 'juliet', 'yiddish', 'new', 'york', 'city'],
#  ['case', 'silent', 'girl', 'dark', 'sherlock', 'holmes', 'tale'],
#  ['chase', 'blue', 'trans', 'theatre', 'festival'],
#  ['mooli', 'london', '|', 'designer', 'camera', 'tech', 'bag', 'hampton'],
#  ['clothing', 'label', '90', 'state', 'mind', 'france'],
#  ['ultimate', 'custom', 'shark', 'rig'],
#  ['conference', 'paradigm', 'shift', 'meeting', '3'],
#  ['climb', '4', 'kidz'],
#  ['tugboat', 'collective', 'inaugural', 'season'],
#  ['geocaching', 'trading', 'cards', 'history', 'series', 'ii'],
#  ['fun', 'n', 'easy', 'cookbook', 'children', 'fun', 'cooking'],
#  ['space', 'trucker'],
#  ['high'],
#  ['club', 'wick3d'],
#  ['modern', 'handmade', 'ceramic', 'paper', 'clay'],
#  ['join', 'complete', 'solo', 'project', 'cd'],
#  ['emotional', 'makayla', 'mommy', 'birthday', 'gift'],
#  ['ashley', 'beauty', 'tool', 'organizer', 'kit'],
#  ['alaska', 'bug', 'bites', 'llc', 'farmers', 'markets', 'launch'],
#  ['quick', 'query', 'relaunch'],
#  ['quick', 'clockwork', 'knight', 'volume', '2'],
#  ['writtenwitheart'],
#  ['uptown', 'juice', 'company', 'local', 'cold', 'pressed', 'goodness'],
#  ['strain', 'war', 'playing', 'card'],
#  ['wood', 'floor', 'fundraiser'],
#  ['water', 'purification', 'system', 'solar', 'evacuate', 'tube'],
#  ['steel', 'cathedrals-', 'short', 'poem', 'digital', 'age'],
#  ['chameleon', 'chronicle', 'color', 'fate'],
#  ['ghost', 'ephemeral', '7-song', 'ep'],
#  ['chic', 'oneclutch', '™'],
#  ['afraid', 'galileo', 'album'],
#  ['paterson', 'falls', 'film', 'festival'],
#  ['spilt', 'milk'],
#  ['thailand', 'country'],
#  ['equinox', 'comic', 'genre', 'fantasy'],
#  ['student', 'operated', 'fabrication', 'lab'],
#  ['nurse', 'mare', 'foal', 'bear', 'die'],
#  ['bird', 'nerd'],
#  ['funky', 'grits', 'fast', 'casual', 'diner', 'pair', 'music', 'menu'],
#  ['great', 'kentucky', 'goblin', 'spree'],
#  ['help', 'community', 'building', 'art', 'austin', 'patterson', 'park'],
#  ['scratch'],
#  ['pierced', 'heart', 'tattoo', 'boutique', 'start'],
#  ['pole', 'diversity', 'showcase', 'acrobatic', 'dance'],
#  ['mckenzie', 'project'],
#  ['new', 'omni', 'wheel', 'mechanical', 'innovation', 'create', 'robot'],
#  ['brewstick', '~', 'carboy', 'ruler'],
#  ['open', 'fiesta', 'arts', 'store', 'dream', 'big', 'san', 'antonio'],
#  ['opening', 'portal', 'dvd'],
#  ['night', 'terrors', 'garden', 'limbo'],
#  ['inclusive', 'toolkit', 'tool', 'ios', 'os', 'x', 'app', 'accessibility'],
#  ['greek4fun'],
#  ['hood', 'brewery'],
#  ['fooju', 'dance', 'collaborative'],
#  ['chris', 'critelli', 'records', 'debut', 'ep'],
#  ['piero', 'marsili'],
#  ['sleep', 'truck'],
#  ['design', 'leatherjacket'],
#  ['sanfilippo', 'wing'],
#  ['road', 'runner', 'multisport', 'smartphone', 'carrier'],
#  ['lego', 'imagination', 'lab'],
#  ['arkham', 'source', 'book'],
#  ['finishing', 'festival', 'funds', 'final', 'stage', 'short', 'film'],
#  ['lonely', 'house', 'films', 'adam', 'hope'],
#  ['adult', 'colour', 'debut', 'album'],
#  ['open', 'a.i.r.'],
#  ['home', 'maine', 'film', 'series', 'homebirth', 'midwives'],
#  ['fusionproject'],
#  ['lego', 'batman', 'zombie', 'genesis', 'series'],
#  ['digitize', 'family'],
#  ['progress', 'steampunk', 'series', 'season', '2'],
#  ['winter', 'writing', 'residency'],
#  ['dome', 'shade', 'sunglass', 'big', 'head'],
#  ['portrait', 'day', '365', 'challenge'],
#  ['xpump', '|', 'turn', 'sound', 'source', 'home', 'theater', 'experience'],
#  ['complete', 'paine', 'skatepark'],
#  ['westward', '8'],
#  ['paperback', 'kindle', 'available'],
#  ['tiba', 'putt', 'personal', 'approach', 'improve', 'putting'],
#  ['ghost', 'herd', 'rescue', 'horse', 'horse', 'people', 'kentucky'],
#  ['gideon', 'epic', 'forge'],
#  ['survyval', 'breakthrough', 'hoodie'],
#  ['farmer', 'bean', 'holy', 'roast'],
#  ['jessica', 'rabbit', 'production'],
#  ['final', 'hour', 'kira', 'kira', 'rainbow', 'unicorn', 'stickers'],
#  ['belleflower', 'feature', 'film'],
#  ['mab', 'mindz', 'sound', 'set', '2014'],
#  ['lei'],
#  ['adaptation', 'wrong'],
#  ['bicycle', 'bus'],
#  ['1st', 'cookbook', 'child'],
#  ['book', 'maxwell'],
#  ['glory', 'kingdoms', 'guandu', 'core', 'set'],
#  ['great', 'apple', 'pie'],
#  ['belong', 'world', 'ackermann', 'repository', 'arts'],
#  ['seven', 'devils', 'feature', 'film'],
#  ['chill', 'puck', 'beverage', 'colder', 'long'],
#  ['heroes', 'stranger', 'fringenyc'],
#  ['project', 'world'],
#  ['quadrato', 'retractable', 'knife', '100'],
#  ['single', 'track', 'contemporary', 'art', 'gallery', 'espresso', 'bar'],
#  ['great', 'fly', 'cup', 'bake'],
#  ['un', 'amour', 'oublie', 'love', 'forget'],
#  ['loop', 'resource', 'strategy', 'game', 'tomorrow', 'leader'],
#  ['contractors', 'create', '3d', 'model', 'prop', 'asset', 'model', '1'],
#  ['sasha', 'fashion', 'spectacle'],
#  ['bass', 'river', 'press'],
#  ['betul',
#   'soykan',
#   'records',
#   'joaquin',
#   'turina',
#   'violin',
#   'work',
#   'cd',
#   'project'],
#  ['food', 'truck', 'world'],
#  ['publish', 'occupy', 'portrait'],
#  ['daweyu', 'hills', 'crop', 'cup'],
#  ['dream', 'project'],
#  ['peripheral', 'vision', 'short', 'film'],
#  ['pimax', 'world', '8', 'k', 'vr', 'headset'],
#  ['4', 'oakland'],
#  ['florida', 'broken', 'kingdom'],
#  ['help', 'start', 'jacksonville', 'paint', 'pottery', 'store'],
#  ['baby', 'boom', 'baby', 'bag'],
#  ['eunoë'],
#  ['scar', 'tissue'],
#  ['stagnant', 'pool', 'enter', 'post', 'production'],
#  ['pro', 'movement'],
#  ['billion', 'dollar', 'project'],
#  ['novel'],
#  ['peak', 'view', 'brewing', 'company'],
#  ['find', 'black', 'love', 'documentary'],
#  ['patch', 'organics'],
#  ['virtual',
#   'addiction',
#   'recovery',
#   'website',
#   'phone',
#   'app/',
#   'saving',
#   'life'],
#  ['fatnek', 'clothing', 'sublimation', 'series', 't', 'shirt'],
#  ['titanium', 'whiskey', 'glass', 'epic', 'drinking', 'glass'],
#  ['child', 'feature', 'length', 'comedy'],
#  ['college', 'spring', 'break', 'review'],
#  ['tall', 'tales', 'evening', 'dance', 'choreojoey'],
#  ['light', 'come'],
#  ['wood', 'fire', 'oven', 'grow', 'community'],
#  ['trap', '2nd', 'record', 'vinyl', 'release'],
#  ['rocky', 'horror', 'saved', 'life', 'fan', 'documentary'],
#  ['song', 'damned', 'jake', 'brock', 'late', 'album'],
#  ['circa',
#   'vitae',
#   'request',
#   'crowd',
#   'fundage',
#   'record',
#   'length',
#   'album',
#   'vinyl'],
#  ['stiletto', 'red', 'new', 'ep'],
#  ['bucks', 'county', 'movie'],
#  ['lazershirts', 'shirt'],
#  ['country', 'christian', 'album', 'title', 'believe'],
#  ['color', 'art', 'party'],
#  ['wholesters-', 'new', 'way', 'whold', 'thing'],
#  ['stamp'],
#  ['steer', 'wearable', 'device', 'save', 'life'],
#  ['ripple', 'analysis', 'bring', 'animation', 'life'],
#  ['croc2pop', 'kid', 'manage', 'dad', 'digital', 'addiction'],
#  ['carolina', 'hot'],
#  ['tulip'],
#  ['ignis', 'fatuus', 'comic', 'project'],
#  ['hoodratz'],
#  ['kingdom', 'space', 'exploration', 'rpg'],
#  ['leonard', 'hodgins', 'components'],
#  ['deluxe', 'rpg', 'handbrain', 'screen'],
#  ['la', 'press', 'soap', 'home', '2', 'minute', 'chemical'],
#  ['c',
#   'r',
#   'o',
#   's',
#   's',
#   't',
#   'o',
#   'w',
#   'n',
#   ' ',
#   'help',
#   'finish',
#   'feature',
#   'film'],
#  ['spice', 'whipped', 'beaten', 'culinary', 'works'],
#  ['grill', 'beer', 'cookbook'],
#  ['womanhood', 'short', 'film', 'fundraiser'],
#  ['sunrise', 'diaries'],
#  ['tommy'],
#  ['solo', 'exhibition', 'recognise', 'gallery', 'step'],
#  ['bromotion'],
#  ['film', 'project', ' ', 'history', 'come'],
#  ['savage', 'thunderscape'],
#  ['mc', 'type', 'bad', 'tattoo', 'vol', '3'],
#  ['man', 'island'],
#  ['completion', 'history', 'kent'],
#  ['grandkid', 'record', 'length', 'album'],
#  ['border'],
#  ['firewater'],
#  ['annulus', 'ring', 'light'],
#  ['gospel', 'jazz', 'independant', 'artist', 'cd', 'project'],
#  ['ugly', 'cartoons', 'poorly', 'draw', 'miserable', 'people'],
#  ['occupy', 'left', 'forum', 'zine'],
#  ['dancing', 'classroom', 'grva', '2013'],
#  ['daily', 'bread', 'story', 'rural', 'greece'],
#  ['monster', 'short', 'film', 'christina', 'morris'],
#  ['black', 'knight', 'brick', 'build', 'bbq', 'grill'],
#  ['boat', 'clyde', 'adventure', 'puget', 'sound'],
#  ['victory', 'record', 'debut', 'ep'],
#  ['daystay'],
#  ['league', 'honor'],
#  ['make', 'bringpack'],
#  ['projecteo', 'tiny', 'instagram', 'projector'],
#  ['digital', 'aristocracy', 'commoner', 'guide', 'digital', 'riches'],
#  ['time'],
#  ['lazy', 'glamour', 'eco', 'underwear', 'soft', 'sustainable'],
#  ['saber', 'design', 'apparel'],
#  ['capture', 'soul', 'town'],
#  ['soft', 'organic', 'cotton', 'underwear', 'give'],
#  ['storybox', 'today'],
#  ['cyberine', '1'],
#  ['poem', 'apostates', 'tale', 'young', 'scientologist'],
#  ['screening', 'mr', 'turner'],
#  ['senior', 'project', 'short', 'film', 'home'],
#  ['treasure', 'trap'],
#  ['suburban', 'daze'],
#  ['flyover', 'farm'],
#  ['focus', 'fan', 'lions', 'tour', '2017'],
#  ['zero', 'dark', 'thirty', 'watch', 'difference'],
#  ['baby', 'name', 'newborn'],
#  ['faithful', 'lesbian', 'mormon', 'story'],
#  ['lazer', 'edge', 'series', 'ebike', 'start', '$', '499'],
#  ['intelishake', 'smart', 'sport', 'drink', 'bottle', '+', 'build', 'storage'],
#  ['bailey', 'golden', 'retriever', 'calendar'],
#  ['painting', 'portrait', 'custom', 'painting'],
#  ['spun', 'monkey', 'dyeworks', 'lounge'],
#  ['reusable', 'giant', 'coloring', 'poster', 'black'],
#  ['lux3', 'wellness', 'lamp'],
#  ['living', 'puppets', 'novel'],
#  ['romantic', 'christmas'],
#  ['project', 'earth', 'monster', 'story', 'bias'],
#  ['yemanja', 'caribbean', 'restaurant', 'bar', 'hostel'],
#  ['eucalyptus', 'wear', 'environmental', 'clothing', 'company'],
#  ['jazz', 'funeral', 'coney', 'island'],
#  ['self', 'illusion', 'best', 'friend', 'worst', 'enemy', 'ep'],
#  ['blak', 'woman', 'dynamik', 'reborn'],
#  ['cause', 'art', 'gallery'],
#  ['thailandmike',
#   'no.1',
#   'portfolio',
#   'hiccup',
#   'tour',
#   'guide',
#   'sketchbook'],
#  ['midwest', 'story'],
#  ['pentimento', 'documentary', 'rene', 'gimpel'],
#  ['mike', 'moreno', 'group', 'fall', '2011', 'release'],
#  ['sansin_band', 'ep'],
#  ['tale', 'sheepland', 'imagination', 'child'],
#  ['kindness', 'stranger'],
#  ['maybe', 'poison'],
#  ['smart', 'dive', 'buddy', 'smartphone', 'dive', 'camera', 'computer'],
#  ['final', 'fantasy', '8', 'viii', 'happen'],
#  ['iphone', 'skin', 'real', 'apple', 'wood'],
#  ['goalzidia', '|', 'let', 'reach', 'goal'],
#  ['mongol', 'art', 'world', 'tour', 'save', 'art'],
#  ['darling', 'june'],
#  ['monster', 'mob', 'fun', 'card', 'game', 'monster', 'family'],
#  ['blacklivesmatter', 'series'],
#  ['sorensen', 'glass', 'studio'],
#  ['free', 'supercomputer'],
#  ['king', 'astronauts', 'documentary'],
#  ['music', 'fame', 'diva', 'djs', 't', 'shirt'],
#  ['æmp', 'dance', 'amiti', 'perry', '+', 'company'],
#  ['flutter', 'flow', 'knitting', 'book'],
#  ['sci', 'fi', 'janitors', 'vs', 'redbull', 'soapbox', 'race'],
#  ['redemption'],
#  ['course', 'stunning', 'fantasy', 'rpg', 'gamemaker', 'studio'],
#  ['secret', 'behavior', 'magazine'],
#  ['michale',
#   'graves',
#   'vagabond',
#   'acoustic',
#   'extremely',
#   'limited',
#   'edition'],
#  ['odyssey', 'skateboards', 'launch'],
#  ['poolpooj'],
#  ['dark', 'forest'],
#  ['shoot', 'thrill', 'shoot', 'kill', 'political', 'sculpture'],
#  ['structure'],
#  ['money', 'shoot'],
#  ['vagabond', 'search', 'homeless', 'father'],
#  ['earthread', 'fabric', 'future'],
#  ['game', 'quick', 'move', 'steal', 'turn'],
#  ['amateur', 'prose', 'book', 'poetry', 'story', 'original', 'art'],
#  ['little', 'boy', 'wonder', 'short', 'film'],
#  ['judge', 'irreverent', 'party', 'game'],
#  ['start', 'herb', 'garden'],
#  ['phantom', 'limbed', 'romantic', 'comedy'],
#  ['defender', 'realm', 'minion'],
#  ['matt', 'whistler', 'movie', 'feature', 'film'],
#  ['undo', 'trilogy'],
#  ['guardian', 'salus', 'book', '1', 'halix', 'series'],
#  ['blakes', 'burgers'],
#  ['build', 'traditional', 'tipi'],
#  ['legend', 'white', 'woman', 'creek'],
#  ['develop', 'new', 'worlds', 'hot', 'chilli'],
#  ['rock', 'audition', 'concert', 'sheri', 'sanders'],
#  ['fragile', 'stephanie', 'mathias', 'ep'],
#  ['second', 'scene', 'culture', 'city', 'project'],
#  ['agrandissement', 'de', 'la', 'brasserie'],
#  ['far', 'christopher', 'rush', 'story', '2'],
#  ['esquilo',
#   'simple',
#   'iot',
#   'development',
#   'wifi',
#   '+',
#   'web',
#   'ide',
#   '+',
#   'cloud'],
#  ['t', 'bone', 'cherry', 'hog'],
#  ['random', 'table', 'wiki'],
#  ['natural', 'face', 'foot', 'body', 'scrub'],
#  ['lds', 'home', 'teaching', 'app', 'visit', 'teaching'],
#  ['mother', 'go'],
#  ['fritz', 'robotic', 'puppet'],
#  ['casper', 'bad', 'spirits', 'lp', 'funding'],
#  ['minecraft', 'hungergames'],
#  ['world', 'fair'],
#  ['campbell', 'glassworks', 'co.'],
#  ['zen', 'tek', 'aquaponics-', 'run', 'air'],
#  ['poem'],
#  ['burn', 'manc', 'festival'],
#  ['airlock', 'bike', 'helmet'],
#  ['lampenschirme', 'und', 'objekte', 'aus', 'französischer', 'handarbeit'],
#  ['woods'],
#  ['green', 'lizzie', 'container', 'truly', 'adapt', 'recycling'],
#  ['well', 'morrissey', 'birthday', 'mix'],
#  ['ride', 'suicide', '2015'],
#  ['3', 'mm', 'aluminum', 'pick', 'plectrum'],
#  ['tara', 'normal'],
#  ['photoshop', 'illustrator', 'designer'],
#  ['profound', 'fatigue', 'produce', 'fly', 'deer', 'theater', 'revise'],
#  ['dungeons', 'heroes'],
#  ['turn', 'messy', 'arduino', 'project', 'clean', 'design', '2', '$'],
#  ['paint', 'entire', 'favela', 'rio', 'de', 'janeiro'],
#  ['open', 'tank'],
#  ['reed', 'bringing', 'tablet', 'read', 'speed'],
#  ['flag', 'world'],
#  ['mover', 'kit', 'kid', 'move', 'building', 'coding'],
#  ['volksdangler', 'hack', 'pocket'],
#  ['p', 'link', 'guitar', 'pickup', 'interchange', 'system'],
#  ['book', 'bare', 'bones', '2'],
#  ['profitstick', '|', 'feel', 'power'],
#  ['mailbox', 'forthcoming', 'album'],
#  ['rocket', 'ranger', 'reloaded'],
#  ['write', 'estimate', 'estimate', 'write'],
#  ['portscenter'],
#  ['like', 'neighborhood'],
#  ['sparklab', 'educational', 'build', 'mobile'],
#  ['karma', 'get', 'face', 'lift'],
#  ['restaurant', 'go', 'grain', 'colchester', 'essex'],
#  ['bull', 'dragon', 'pop', 'restaurant', 'project'],
#  ['torque'],
#  ['stage', 'stage', 'music', 'theatre'],
#  ['phochron', 'xa', 'film', 'camera', 'shutter', 'speed', 'tester'],
#  ['vivian', 'dog', 'moves', 'brooklyn'],
#  ['darkghost', 'assignment', 'book', 'brothers'],
#  ['mick', 'life'],
#  ['free', 'soap', 'start', 'soap', 'maker'],
#  ['nice', 'set', 'shells~~', 'handmade', 'seashell', 'jewelry'],
#  ['shatter', 'restore'],
#  ['barry', 'county', 'milk'],
#  ['giant', 'communist'],
#  ['surf', 'right', 'documentary', 'inspire', 'cold', 'water', 'surfers'],
#  ['survive', 'treasure', 'island', 'choose', 'path'],
#  ['talega', 'holiday', 'annual', 'halloween', 'light'],
#  ['help', 'publish', 'picture', 'kid', 'book'],
#  ['moon', 'eye', 'view', 'save', 'world'],
#  ['safe', 'food', 'makeup', 'household', 'product'],
#  ['geek', 'seeker'],
#  ['quern', 'undying', 'thought'],
#  ['nabil', 'karim', '|', 'anise', 'k', '~', 'bicentenary', 'album'],
#  ['destroy', 'slackers', 'animated', 'feature', 'film'],
#  ['seeker', 'aerial', 'video', 'drone'],
#  ['quikceipt', 'paperless', 'solutions'],
#  ['splendid', 'entities', 'catalog', 'project'],
#  ['champion', 'children', 'vol', '1', 'know', 'champ', 'fund'],
#  ['dragonfly'],
#  ['ale', 'house', 'string', 'band', 'debut', 'album'],
#  ['new', 'cornell', 'hurd', 'band', 'cd', 'great', 'new', 'song', 'love'],
#  ['dodecahedrone', 'rpg', 'post', 'apocalyptic', 'robots', 'd12s'],
#  ['follow', 'help', 'barney'],
#  ['da', 'dome', 'roller', 'skating', 'rink', 'brooklyn', 'new', 'york'],
#  ['tankwork', 'cooperative', 'tank', 'action'],
#  ['winter', 'mind', 'ep', 'funding'],
#  ['12', 'day', 'commision', 'spree', '1', 'custom', 'hand', 'draw', 'art'],
#  ['charlene', 'kaye', 'make', 'new', 'record', 'animal', 'love'],
#  ['chefs', 'open', 'shakewell', 'bar', 'kitchen'],
#  ['lonely', 'himalayas'],
#  ['phrenic', 'interactive', 'comic', 'alternate', 'reality', 'game'],
#  ['carnival', 'arts', 'exhibit', 'miami', 'international', 'airport'],
#  ['unassisted', 'ep', 'revolution'],
#  ['dead', 'night'],
#  ['wazupio'],
#  ['daggermond'],
#  ['choose', 'fate', 'film', 'put', 'charge'],
#  ['lock', 'jeans'],
#  ['dos', 'pueblos', 'tecnicos'],
#  ['geekholder', 'hold', 'phone', 'tablet', 'laptop', 'screen'],
#  ['maze', 'slime'],
#  ['long',
#   'range',
#   'murs',
#   'band',
#   'gps',
#   'tracker',
#   'smartphone',
#   'communicator'],
#  ['sins', 'roleplaying', 'game'],
#  ['cakehouse', 'layer', 'studios', 'comics', 'zine'],
#  ['1of10', 't', 'shirt', 'protest', 'trump', 'putin', 'connection'],
#  ['doctor', 'menace', 'foonf'],
#  ['bird', 'eye', 'view', '1892', 'map', 'atlanta', '1000', 'piece', 'puzzle'],
#  ['prelude', 'conversation'],
#  ['new', 'social', 'network'],
#  ['autopsy', 'die', 'man'],
#  ['art', 'lover', 'place'],
#  ['bona', 'dea', 'gluten', 'free', 'goodness'],
#  ['got', 'beat', 'fbi', 'year', 'old'],
#  ['pony', 'death', 'ride', 'make', 'album'],
#  ['love', 'animals', 'debut', 'ep', 'project'],
#  ['unknown', 'arizona'],
#  ['bridge', 'sighs', 'short', 'film', '2'],
#  ['legendary',
#   'steamboat',
#   'springs',
#   'band',
#   'record',
#   'album--',
#   '30',
#   'year'],
#  ['luxury', 'timepiece', 'system', 'minimal', 'everyday', 'watch', 'system'],
#  ['rest', 'stop', 'restaurant'],
#  ['maree', 'v.', 'state', 'documentary'],
#  ['girdy', 'webcomic'],
#  ['magic', 'tower'],
#  ['da', 'stooges', 'wipeout', 'surfaris'],
#  ['lobster', 'art', 'project'],
#  ['quartz', 'bottle', 'water', 'purification', 'self', 'cleaning', 'bottle'],
#  ['follow', 'racine', 'east', 'africa', 'safari', 'rally'],
#  ['sky', 'lounge', 'visual', 'ep'],
#  ['acnedust',
#   '™',
#   'organic',
#   'acne',
#   'treatment',
#   '-acne',
#   'dust',
#   'sleep',
#   'powder'],
#  ['legendary', 'cobo'],
#  ['philip', 'brittany', 'burton', 'new', 'album', 'fear'],
#  ['mason', 'ry', 'silicone', 'koozie'],
#  ['shirt', 'east', 'idaho', 'aquarium'],
#  ['new', 'lp', 'release', 'shape', 'earth'],
#  ['rinsekit', 'revolutionary', 'portable', 'shower'],
#  ['singularity'],
#  ['taluva', 'deluxe', 'version'],
#  ['calvin', 'thomas', 'make', 'october', 'sky', 'album'],
#  ['wilmer', 'wilson', 'iv', 'summer', 'art', 'residency', 'nls'],
#  ['gladys', 'sing'],
#  ['2012', 'lake', 'george', 'music', 'festival'],
#  ['seek', 'shelter', 'vol', '3', 'rescue', 'animal', 'ho'],
#  ['boutique', 'disco', 'flash', 'québec'],
#  ['fail', 'safe', 'project', 'length', 'album'],
#  ['door', 'feature', 'film', 'finishing', 'fund'],
#  ['decorative', 'oxygen', 'tank', 'bags', 'amarijade', 'inc.'],
#  ['commit', 'suicide'],
#  ['scarf', 'cuff'],
#  ['behold', 'uprising', 'ep'],
#  ['johnny', 'strange'],
#  ['panini', 'company'],
#  ['legendary', 'warriors', 'productions'],
#  ['statue', 'doc', 'u.s.marines', 'corpsman'],
#  ['stagecoach', 'mary'],
#  ['knot', 'app'],
#  ['powerbark-"meal', 'run', 'dog'],
#  ['tenacious',
#   'exclusive',
#   'scott',
#   'tolleson',
#   'uncle',
#   'argh',
#   'noir',
#   'mini',
#   'qee'],
#  ['centennial', 'armenian', 'genocide', 't', 'shirt'],
#  ['mini', 'flashlight', 'fire', 'starter'],
#  ['big', 'inside'],
#  ['jordon', 'bould', 'butcher', 'blocks'],
#  [],
#  ['somo', 'mixtape'],
#  ['little', 'women', 'graphic', 'novel', 'project'],
#  ['joy', 'ike', 'record', '3rd', 'length', 'album', 'let'],
#  ['lotus', 'earring'],
#  ['adults'],
#  ['bohemian', 'book', 'project'],
#  ['viking', 'hood', 'alive', 'kick'],
#  ['tenor', 'journey', 'german', 'land'],
#  ['vanilley', 'bean', 'treats', 'life', 'sweet', 'moment'],
#  ['wheeling', 'careen', 'wander', 'emp'],
#  ['fireball', 'newsflash', 'crosswords', '2015', '16'],
#  ['kung', 'fu', 'bellydance', 'masters'],
#  ['academia', 'de', 'música', 'impulsarte.org'],
#  ['world', 'year'],
#  ['living', 'coaster', 'beverage', 'coaster', 'grow', 'plant'],
#  ['naturalia', 'young', 'adult', 'book', 'surprise', 'girlfriend'],
#  ['chop', 'sooey', 'charm', 'pin'],
#  ['wheelhouse', 'farm', 'table', 'restaurant', 'st', 'joseph', 'il'],
#  ['galaxy', 'trian', 'new', 'order'],
#  ['air', 'air', '~', 'portable', 'air', 'quality', 'detector'],
#  ['conduit', 'sports', 'dynamic', 'bone', 'conducting', 'headphone'],
#  [],
#  ['tableau', 'vivant', 'delirium', 'constructions', 'global', 'tour'],
#  ['seth', 'pineapple', 'mango', 'salsa'],
#  ['day', 'x'],
#  ['day', 'time', '365', 'day', 'photograph'],
#  ['free', 'world', 'brand', 'clothing', 'co.'],
#  ['planet', 'hell', 'post', 'apocalyptic', 'web', 'series'],
#  ['little', 'falcon', 'need', 'help'],
#  ['customizable', '3d', 'printed', 'miniatures'],
#  ['short', 'defender', '©'],
#  ['heya', 'toothbrush', 'holder', 'simple', 'clean', 'bacteria', 'away'],
#  ['imminent'],
#  ['love', 'tongue', 'death', 'eye'],
#  ['pocket', 'parking', 'meter'],
#  ['mechabrick', 'minifig', 'mecha', 'board', 'game', 'model'],
#  ['cat',
#   'cafe',
#   'mad',
#   'coffee',
#   'shop',
#   'remodel',
#   'expansion',
#   'real',
#   'food'],
#  ['pollock', 'l’acchiappa', 'panzane'],
#  ['unconditional', 'hope', ' ', 'survivors', 'story'],
#  ['finish', 'amish', 'appeal'],
#  ['gamerline', 'clothing', 'starter', 'business', 'need', 'help'],
#  ['sports', 'city'],
#  ['vyu360', '™', '4', 'k', 'procam'],
#  ['justifier'],
#  ['sinner', 'iii', 'supernatural', 'horror', 'comic', 'night', 'motel'],
#  ['ez', 'master', 'double', 'boiler', 'attachment', 'stand', 'mixer'],
#  ['shakespeare', 'fund', 'fund', 'question'],
#  ['monkey', 'paw'],
#  ['charlie', 'vs', 'goliath'],
#  ['new', 'madysin', 'hatter', 'ep', 'title', 'pretty', 'little', 'fool'],
#  ['release', 'black', 'heart', 'album'],
#  ['bad', 'day', 'blue'],
#  ['pappino', 'dein', 'foto', 'auf', 'einem', 'recyceltem', 'kartonrahmen'],
#  ['coach', 'life', 'times', 'shawn', 'tompkins'],
#  ['life', 'online'],
#  ['promise', 'tempus', 'film'],
#  ['grace', 'gentle', 'playing', 'cards', 'lunzi'],
#  ['kingdom', 'angelic', 'war', 'card', 'game'],
#  ['april', 'alayne', 'studio'],
#  ['ultra', 'way', 'cool', 'teaching', 'puppet'],
#  ['chain', 'mail', 'creation'],
#  ['3d', 'film', 'perfect', 'divorce'],
#  ['average', 'grill', 'cheese'],
#  ['supplicant', 'age', 'dissidence'],
#  ['diarios', 'de', 'viaje', 'película'],
#  ['alé', 'garza', 'h.a.r.d.core'],
#  ['kind', 'mind', 'wise', 'souls', 'launch', 'collection'],
#  ['bring', 'seattle', 'geekly', 'podcast'],
#  ['galactic', 'princess'],
#  ['la', 'feria', 'concreta', 'documentary', 'film', 'installation'],
#  ['debut', 'original', 'album', 'mindy', 'stratton'],
#  ['night_rider'],
#  ['xybear', 'heroes'],
#  ['archive', 'warhood', 'odyssey'],
#  ['vaudezilla', 'chicago', 'burlesque', 'coloring', 'book', 'matt', 'hansel'],
#  ['homestyle', 'video', 'installation', 'delicious', 'spectacle'],
#  ['4', 'color', 'press', '5th', 'street', 'garment', 'company'],
#  ['maltese', 'brewing', 'company'],
#  ['hollow'],
#  ['perfect', 'plan'],
#  ['dionysius', 'games', 'indy', 'games'],
#  ['music', 'production'],
#  ['markus', 'mann', 'music', 'cd', 'production', 'tour'],
#  ['tropical', 'bat', 'house'],
#  ['wade', 'water', 'gallery'],
#  ['woodland', 'banners', 'poetry', 'walk'],
#  ['soul', '2nd', 'ep', 'record'],
#  ['home', 'jug', 'decal', 't', 'shirt', 'trophy', 'tailgate'],
#  ['battle', 'orion', '2'],
#  ['pretty', 'ugly', 'awp'],
#  ['homebound', 'film', 'transform', 'image', 'latinos'],
#  ['nepenthe', 'short', 'film'],
#  ['jesus', 'homeless', 'woman', 'clay', 'bronze'],
#  ['audio', 'heroin', 'chic', 'cyber', 'doll'],
#  ['self', 'produce', 'debut', 'album'],
#  ['bizarre', 'case', 'globular', 'gullet'],
#  ['earth', 'wall', 'ii', 'rammed', 'earth', 'sculpture'],
#  ['boys', 'bow', 'tie', 'tour'],
#  ['inches', 'short', 'film'],
#  ['teslatronix-', 'tesla', 'power', 'masse'],
#  ['wood', 'gift', 'personal', 'memory'],
#  ['inspire', 'x', 'sound'],
#  ['pastor', 'damien', 'season'],
#  ['speculative',
#   'relationship',
#   'sci',
#   'fi',
#   'romance',
#   'comics',
#   'anthology'],
#  ['veteran', 'art', 'david', 'geig'],
#  ['marketplace', 'crowdfunded', 'product'],
#  ['note', 'self'],
#  ['orillia', 'summer', 'theatre', '2016'],
#  ['maria', 'sweet', 'sing'],
#  ['aurora', 'chronicles', 'hero'],
#  ['aj', 'handmade', 'style'],
#  ['kickstart', 'art'],
#  ['paladin', 'warrior', 'charlemagne'],
#  ['john', 'lennon', 'peace', 'chance', 'book'],
#  ['jessica', 'jewelry'],
#  ['creative', 'community'],
#  ['green', 'light', 'radio', 'broadcast', 'arise', 'festival', '2014'],
#  ['poetry', 'safe', 'new', 'good', 'reading', 'film'],
#  ['1', 'man', '10', 'day', '100', '+', 'canvas'],
#  ['bt', 'block', 'tower'],
#  ['versa', 'tool'],
#  ['dreamafrica'],
#  ['failure', 'jacket'],
#  ['dayz', 'come', '+', '=', 'new', 'worship', 'project'],
#  ['healthy', 'sustainable', 'clothing'],
#  ['new', 'york', 'travel', 'sightseeing', 'video', 'blog'],
#  ['magpi', 'magazine', 'virtual', 'reality'],
#  ['loquat', 'arsonist', 'short', 'film', 'music', 'video'],
#  ['unique', 'collage'],
#  ['corey', 'coffee', 'bar'],
#  ['inhale', 'sunrise'],
#  ['son', 'odin', 'fantasy', 'football'],
#  ['chimera', 'station', 'euro', 'edition'],
#  ['ghetto', 'love', 'write', 'weedie'],
#  ['ping', '2', 'attack', 'sphere', 'wii', 'u', 'ps3', 'steam'],
#  ['loud', 'bicycle', 'car', 'horn', 'bike'],
#  ['vince', 'durden', 'world', 'eco', 'friendly', 'backpack'],
#  ['2000', 'mile'],
#  ['black', 'mint', 'playing', 'cards'],
#  ['holiday', 'experience', '2014', 'jazzy', 'christmas', 'celebration'],
#  ['renwick', 'ally', 'album', 'ryan', 'angell', 'aka', 'andrew', 'juco'],
#  ['amphibious', 'red', 'couch'],
#  ['rabbitwild', 'shelter', 'wilderness'],
#  ['leah', 'stein', 'dance', 'company', '10th', 'anniversary', 'concert'],
#  ['parthia', 'saffron', 'door', 'thread', 'time'],
#  ['upcycled', 'planter'],
#  ['youth', 'education', 'tv', 'talk'],
#  ['mango', 'pineapple', 'habanero', 'toe', 'curling', 'hot', 'lava', 'sauce'],
#  ['epic', 'backpacking', 'dynasty', 'global', 'millennial', 'revolution'],
#  ['ainsley', 'band', 'uk', 'tour'],
#  ['fantuckfastic', 'onesie'],
#  ['iwish', 'sigil', 'magic'],
#  ['mars', 'transit', 'game', 'funspace', 'circle', 'friends', 'bo', 'regard'],
#  ['self', 'sufficient', 'water', 'filtration', 'system', 'kind'],
#  ['sawyer', 'dinosaur', 'child', 'book'],
#  ['magician', 'cat', 'print', 'edition', 'ebook'],
#  ['berwyn', 'project', 'ep', 'mc', 'type', 'thewoods'],
#  ['undive', 'dark', 'sea', '500', 'm'],
#  ['iviou', 'future', 'buy', 'sell', 'online'],
#  ['rustic', 'reclaimed', 'furniture', '100', 'hand'],
#  ['lonesome', 'days', '1st', 'studio', 'album'],
#  ['league', 'legends', 'cosplay'],
#  ['lose', 'like', 'human', '2017'],
#  ['animal', 'playing', 'card'],
#  ['entertain', 'photobook', 'lois', 'golding'],
#  ['see', 'swiss', 'picture', 'people', 'world', 'engineering'],
#  ['love', 'gut', 'high', 'school'],
#  ['cafe', 'gangster'],
#  ['rivers', 'monroe', 'fall', 'tour', '2016'],
#  ['golf', 'alpha', 'yankee', 'lgbt', 'human', 'rights', 'documentary'],
#  ['colombian', 'art', 'gallery', 'la', 'magic', 'realism', 'strike'],
#  ['turn'],
#  ['animal', 'masks', '10', 'week'],
#  ['dancer', 'descend', 'mount', 'kenya', 'memoir'],
#  ['press', 'start', 'bar'],
#  ['zombme'],
#  ['t', 'shirt', 'design', 'startup'],
#  ['zisil'],
#  ['faceless', 'neil'],
#  ['starbird', 'land', 'earth', 'debut', 'album', 'time'],
#  ['bryan', 'wilton', 'print', 'audio'],
#  ['downtown', 'mural'],
#  ['zombie', 'usb', 'keychain', 'zed', '1.0'],
#  ['skullgarden', 'linocut', 'print', 'project'],
#  ['soundtrack', 'story', 'dj'],
#  ['sweet', 'surrender'],
#  ['alaina', 'blair', 'cd', 'tour', 'project'],
#  ['cemetery', 'angels', 'photographic', 'book'],
#  ['sledge', 'leather', 'reply', 'to(insert', 'large', 'ass', 'metal', 'label'],
#  ['kensaku', 'shinohara', 'mana', 'spring', '2014'],
#  ['help', 'exhibit', 'art', 'geordanna', 'artist'],
#  ['exoskeleton',
#   'assault',
#   'squad',
#   'hura',
#   'technocracy',
#   '15',
#   'mm',
#   'sci',
#   'fi'],
#  ['moar', 'online', 'multiplayer', 'fighting', 'game'],
#  ['esperanza', 'gang', 'intervention', 'photo', 'documentary'],
#  ['jakten', 'på', 'makten', 'brädspelet', 'om', 'svensk', 'politik', '2016'],
#  ['create', 'liberal', 'america'],
#  ['cook', 'fire', 'disaster', 'cookbook'],
#  ['violet', 'tendencies', 'star', 'mindy', 'cohn', 'dvd'],
#  ['disgruntled', 'deck', 'original', 'card', 'game', 'veteran'],
#  ['come', 'sea', 'ambitious', 'short', 'film'],
#  ['elemental', 'burn', 'city'],
#  ['sol', 'mcnally', 'photography'],
#  ['45', 'led', 'packlight', 'let', 'bend', 'light', 'need'],
#  ['flowpaw', 'learn', 'computer', 'code', 'build', 'gizmo'],
#  ['home', 'ground'],
#  ['pixel', 'press', 'draw', 'video', 'game'],
#  ['sexy', 'action', 'accounting', 'myths', 'short', 'film'],
#  ['moment', 'iphone', '7', 'well', 'camera'],
#  ['poetry'],
#  ['post', 'election', 'student', 'voices', 'hope', 'resistance'],
#  ['ion', 'music', 'detect', 'mood', 'light', 'bluetooth', 'low', 'energy'],
#  ['bring', 'patrizi', 'family', 'food', 'truck', 'experience'],
#  ['musical', 'help', 'trouble', 'number'],
#  ['fuse', 'defiance', 'album', '2015'],
#  ['mobile', 'drool', 'central'],
#  ['awfully', 'sudden', 'album'],
#  ['parallel', 'print', 'edition', 'run', 'come', 'age', 'novel'],
#  ['want', 'apply', 'x', 'factor', 'music', 'project'],
#  ['beat', 'track'],
#  ['lovers', 'lose', 'feature', 'film'],
#  ['coon', 'age', 'volume'],
#  ['live', 'dorothy', 'parker', 'hollywood', 'fringe'],
#  ['traditional', 'astrophotography', 'window', 'cygnus'],
#  ['hole', 'wall', 'hector', 'records', 'debut', 'studio', 'album'],
#  ['lighten'],
#  ['surrender', 'spirit', 'creative', 'writing', 'project', 'phase', '1'],
#  ['newton', 'wildlife', 'adventures'],
#  ['secret', 'tomato', 'project'],
#  ['xstink'],
#  ['open', 'online', 'gallery', 'great', 'dinosaur', 'art', 'artist'],
#  ['meditation', '8', 'simple', 'technique', 'beginner'],
#  ['qi', 'aerista', 'ultimate', 'wi', 'fi', 'enabled', 'smart', 'tea', 'maker'],
#  ['art', 'mitch', 'foust', '2017', 'yearbook'],
#  ['bring', 'victorian', 'life'],
#  ['chat', 'choice', 'gaming'],
#  ['thank', 'letters', 'krys'],
#  ['margoh', 'make', 'legend', 'drink', 'london', 'style'],
#  ['original', 'painting', '£', '10'],
#  ['opuntia'],
#  ['debut', 'hip', 'hop', 'album', 'mikelwj'],
#  ['shattered',
#   'shards',
#   '3d',
#   'printable',
#   'fantasy',
#   'war',
#   'games',
#   'scenery'],
#  ['temple', 'flower', '|', 'vibrant', 'activewear', 'yoga', 'apparel'],
#  ['scorn',
#   'star',
#   'american',
#   'idol',
#   'alum',
#   '2x',
#   'grammy',
#   'nominee',
#   'chip'],
#  ['project'],
#  ['maori', 'mbt', 'awareness', 'centre'],
#  ['weekly', 'video', 'series'],
#  ['bike', 'pouch'],
#  ['global', 'intersection', '13', 'world', 'materials', 'method'],
#  ['zombie', 't', 'shirts', 'hoodies'],
#  ['alwaysremembered.com', 'new', 'way', 'remember', 'love', 'one'],
#  ['moustache', 'bow', 'tie', 'project', 'mo', 'bros', 'mo', 'sistas'],
#  ['official', 'music', 'video', 'single', 'forever'],
#  ['prelude', 'psychological', 'survival', 'horror', 'game'],
#  ['bible', 'app'],
#  ['een', 'leven', 'lang', 'flow'],
#  ['garment', 'collective', 'ethically', 'source', 'redemptively'],
#  ['beginning', 'mark', 'barnes'],
#  ['challis', 'effect', 'heart', 'build', 'graveyard'],
#  ['log'],
#  ['maui', 'maine', '2017', '|', 'claybourne', 'tour'],
#  ['worlds', 'adventure', 'fantasy', 'realms'],
#  ['perfect', 'boots', 'fernando', 'berlin'],
#  ['dihydrogen', 'monoxide', 'conspiracy'],
#  ['3d', 'survival', 'kit'],
#  ['ton', 'music', 'buck'],
#  ['adoree', 'european', 'promo', 'tour', 'summer', '2011'],
#  ['read', 'bible', '1', 'year', 'card', 'system'],
#  ['rob', 'wiley', 'custom', 'leatherwork'],
#  ['n3on', 'love', 'official', 'launch'],
#  ['littlerp', 'affordable', 'flexible', 'open', '3d', 'resin', 'printer'],
#  ['fallen', 'guardian', 'angels', 'film', 'project'],
#  ['monocrane', 'reversible', 'leather', 'book', 'bag', 'photochromic', 'ink'],
#  ['hilarious', 'film', 'call', 'mooo'],
#  ['hi', 'help', 'publish', 'wizard', 'legacy'],
#  ['bondurant', 'brothers', 'distillery'],
#  ['summer', 'goth', '2016', 'finish', 'fund'],
#  [],
#  ['duo', 'diy', 'twin', 'lens', 'reflex', 'camera', 'instant', 'film'],
#  ['western', 'sydney', 'arts', 'academy'],
#  ['pursu', 'passion', 'career'],
#  ['crazy', 'train'],
#  ['1862', 'railway', 'mania', 'eastern', 'counties'],
#  ['life'],
#  ['pongcaddie', 'save', 'ball', 'beer', 'pong', 'nets'],
#  ['julia', 'fanning', 'debut', 'ep'],
#  ['sprite', 'lamp', 'dynamic', 'lighting', '2d', 'art'],
#  ['z', 'day', 'lena', 'pendleton'],
#  ['road', 'italy'],
#  ['immersive', 'cinema'],
#  ['bbq', 'dragon', 'barbecue', 'fire', 'supercharger'],
#  ['dineamics'],
#  ['unearthing'],
#  ['uncle', 'samta', 'final', 'hour'],
#  ['know', 'like'],
#  ['igloo', 'glass', 'world', 'cool', 'beer', 'glass'],
#  ['treasure', 'book', 'cover'],
#  ['come', 'sweat'],
#  ['finish', 'el', 'toro', 'tot', 'food', 'trailer'],
#  ['madjacks',
#   '|',
#   'ski',
#   'pain',
#   'free',
#   '|',
#   'walk',
#   'normally',
#   '|',
#   'affordably'],
#  ['phil', 'king', 'leeland'],
#  ['elbow', 'knees', 'cripple', 'crush', 'ep'],
#  ['broadway', 'come', 'denver', 'scholarship', 'fund'],
#  ['bedroom', 'behavior', 'lingerie'],
#  ['love', 'libya'],
#  ['amazing', 'tales', 'wasted', 'lands', 'inaugural', 'issue', 'pre', 'sale'],
#  ['geex', 'season'],
#  ['old', 'soul', 'lion'],
#  ['sleep', 'board'],
#  ['kevin', 'woody', 'solo', 'album'],
#  ['norman', 'einstein', 'normanthology'],
#  ['donate', 'money', 'music', 'video', 'shoot', 'september'],
#  ['kronos', 'pino', 'family', 'ranch'],
#  ['stolen', 'crystals'],
#  ['low', 'shoulders', 'short', 'film'],
#  ['endless', 'whispers', 'cycle', 'featurettes'],
#  ['dexter', 'etsy', 'shop', 'expansion'],
#  ['inflatable', 'jake', 'band', 't', 'shirt'],
#  ['artisan', 'vinegar'],
#  ['saga', 'splintered', 'realm'],
#  ['coolrunnings', 'physical', 'release', 'reality'],
#  ['51st',
#   'studios',
#   'unplugged',
#   'wood',
#   'headphones',
#   'feature',
#   'bluetooth'],
#  ['film'],
#  ['edgar', 'wallace', 'jr.', 'get', 'saxy', 'studio', 'new', 'c.d.'],
#  ['cirsova', '2017', 's', '5', '6', 'lovecraft', 'swords', 'space', 'ships'],
#  ['lego', 'chess', 'set'],
#  ['feed', 'fingers', 'double', 'album'],
#  ['telemetry', 'webisode'],
#  ['song', 'word'],
#  ['chris', 'custom', 'build', 'pc'],
#  ['record', 'ben', 'cyllus', 'new', 'project'],
#  ['motion', 'present', 'moments', 'define', 'nyc'],
#  ['letter', 'basic', 'training'],
#  ['major', 'factor'],
#  ['watch', 'inspire', 'life'],
#  ['affordable', 'computer', 'controlled', 'quilting', 'system', 'add'],
#  ['manboy', 'lp', 'oliver', 'manning'],
#  ['reds.box', 'privacy', 'cloud'],
#  ['odyssey', 'homer', 'amazing', 'youth', 'actors', 'giant', 'puppets'],
#  ['namm', 'marketing', '-keepe', 'big', 'dog'],
#  ['debut', 'ep', 'album', 'promotion'],
#  ['doodle', 'creatively', 'interactive', 'children', 'book'],
#  ['ninjutsu', 'pencil', 'holder'],
#  ['bocusini', 'world', 'plug', 'play', '3d', 'food', 'printing', 'system'],
#  ['conservative', 'theatre', 'festival', 'columbus', 'oh', '1/7/17'],
#  ['spread', 'love'],
#  ['run', 'fast'],
#  ['aivot'],
#  ['fashionrider', 'tell', 'video', 'documentary'],
#  ['shred', 'pro', 'rider', 'snowboard', 'game'],
#  ['riddle', 'sphinx'],
#  ['weekend', 'love'],
#  ['los', 'angeles', 'women', 'theatre', 'festival', '24th', 'anniversary'],
#  ['gender', 'neutral', 'pair', 'dance', 'explore', 'gender', 'role', 'dance'],
#  ['illusion', 'reality'],
#  ['daniel', 'ordinary', 'tragedy', 'new', 'musical'],
#  ['glass', 'paradise'],
#  ['genesis', 'collection'],
#  ['attention', 'life', 'extreme'],
#  ['covalence', 'molecule', 'building', 'game'],
#  ['professor',
#   'vogel',
#   'alternative',
#   'history',
#   'machine',
#   'i&a',
#   'issue',
#   'iii'],
#  ['monadnock', 'gymnastics'],
#  ['banaau', 'get', 'level'],
#  ['solo', 'art', 'miami'],
#  ['cinema', 'verde'],
#  ['douse', 'sauce', 'story'],
#  ['king', 'guild'],
#  ['nostalgic', 'restoration', 'youth'],
#  ['beast',
#   'spearpointe',
#   'book',
#   '1',
#   '10',
#   'new',
#   'epic',
#   'fantasy',
#   'series'],
#  ['napa', 'valley', 'private', 'label', 'wine'],
#  ['human', 'want', 'sf', 'anthology'],
#  ['ian', 'mahan', 'new', 'album', 'little', 'moment'],
#  ['gbs', 'detroit', 'present', 'daniel', 'harrison', '$', '2', 'highway'],
#  ['pot', 'coffee'],
#  ['pet', 'beds'],
#  ['paprika', 'short', 'film'],
#  ['dark', 'shade', 'fado'],
#  ['life', 'career', 'change', 'dream', 'camera', 'goal'],
#  ['lightbulb', 'terrarium', 'hand', 'mini', 'terrarium'],
#  ['dead', 'burger', 'abomination', 'films'],
#  ...]

# %%
corpus_spacy = []

for i in range(0, len(tokens)):
    
    token = " ".join(tokens[i])
    corpus_spacy.append(token)

# %%
corpus_spacy
# Out:
# ['songs adelaide abullah',
#  'greet earth zgac arts capsule et',
#  'hank',
#  'toshicapital rekordz need help complete album',
#  'monarch espresso bar',
#  'support solar roasted coffee green energy   solarcoffee.co',
#  'chaser strips strips shot b*tch',
#  'jesus madmen',
#  'lisa lim new cd',
#  'cottage market',
#  'g spot place gamer connect eachother pro',
#  'tombstone old west tabletop game miniature 32 mm',
#  'survival rings',
#  'beard',
#  'note london',
#  'mike corey darkness light album',
#  'boco tea',
#  'cmuk shoe life feet',
#  'mikeyj clothing brand fundraiser',
#  'alice wonderland g minor',
#  'mountain brew quest alcohol sustainability',
#  'book zoo mini comic',
#  'matt cavenaugh jenny powers 1st album',
#  'superhero teddy bear',
#  'permaculture skill',
#  'rebel army origins heroic story major gripe',
#  'moon animated short film',
#  'daily brew coffee',
#  'ledr workbook tough journal',
#  'feather cast furled fly fishing leader',
#  'bb130a',
#  'chris eger band new nashville record',
#  'squatch watchers',
#  'arrows sound debut album',
#  'zen america film zen buddhism north america',
#  'galaxy winnie friends',
#  'help scott reynolds new record',
#  'phil younger slow official music video',
#  'return book project',
#  'penny bingo playing card game fun family',
#  'studio premiere',
#  'street music new orleans',
#  'hot chicken take',
#  'star snowman',
#  'seas iron',
#  'in)visible empire tees',
#  "i'll dreams narrative feature film",
#  'h2o underwater portrait',
#  'skateframes photo frame recycle skateboard wood',
#  'teacher travels china',
#  'mother live fit yoga dvd mom baby',
#  'mobile barbecue catering trailer',
#  'follow novel',
#  'underwater',
#  'fanalyzers view stand',
#  'empire sea',
#  'teacher sky',
#  'fashion removeable decoration jewel accessory hells shoe',
#  'russia love simon',
#  'hiit bottle ™',
#  'jurassicjurassix guilt',
#  'safe home',
#  'pantochino productions cinderella skeleton musical',
#  'shreddit privacy reddit',
#  'fly carpets azerbaijan iran turkey anatolia',
#  'diposta liberate people postal mailbox',
#  'future pass debut cd jazz trio',
#  'vote trump candle',
#  'complicate ariana salome',
#  'secular solstice 2014',
#  'uncommon rhythm season',
#  'legacy svarog | unique 3d action rpg adventure game',
#  'anvil beard',
#  'awe antediluvian war extermination tactical card game',
#  'road shire',
#  'spiral electric skylab recording',
#  'local shirt',
#  'home anthology',
#  'diet thank lose weight',
#  'onrust project row treaty 1613',
#  'coffee box',
#  'tu sabes know music collaboration daya edu',
#  'silence hollowind urban fantasy rpg',
#  'p o v comic literary anthology',
#  'little shop horrors browncoat theatre',
#  'dark waters project',
#  'los angeles international student film festival',
#  'bob contemplate end',
#  'girl bathroom',
#  'good spray bottle sureshot',
#  'new lasagna',
#  'reality season 3',
#  'backroad ep processing cost',
#  'disaster area podcast',
#  'titanium edc bottle opener',
#  'eat like gilmore cookbook',
#  'bad example southern trailer park fairy tale indie short',
#  'patty party mumblecore horror feature',
#  'bold threadz',
#  'happy fix usa',
#  'smb project album',
#  'daytrader financial board game',
#  'irninja control tv simple press button',
#  'mama meatballs',
#  'ebony child music artist drop new album comic book film',
#  'alpha omega e.p.',
#  'carriage',
#  'allthis tv',
#  'legendary yd 2016 tour',
#  'memory lane  ',
#  'jane brown story courage survival love',
#  'case lynk emergency iphone charge sync cord',
#  'cat pre professional ballerina',
#  'wordwright re·de·fin·e word play',
#  'serino pizza rolling pizza lab food truck',
#  'photobook life japan',
#  'operation stuff',
#  'xi3 help usher post pc era',
#  'help wood shop buy lathe hopefully laser engraver',
#  'spirit asunder',
#  'store facades paintings pittsburgh',
#  'trackside independent documentary feature marshal',
#  'brandi emma promote new 5-song ep   pre order right',
#  'gantish online reward chart creator parent',
#  'urbnpop chris hamer sketchbook',
#  'sellegg start classified site',
#  'farmer brown analogy farm game age',
#  'seven rays',
#  'short stories love poems',
#  'david larocca star spawn',
#  'calendar cat',
#  'dogma short film',
#  'project u neek',
#  'architecture design website',
#  'notmypresident protest tee',
#  'musical light suit',
#  'go 61 second',
#  "ya science fiction comedy book series zeek kim'lo",
#  'rise star unsigned artist compilation album',
#  'musical stage escenario musical',
#  'hydra dice',
#  'islamic world strategic gaming islamic value',
#  'hangar 1 foundation',
#  'adele heart go edinburgh',
#  'odin android smart projector carry pocket',
#  'jenny photography start business travel',
#  'kaleidoscope man',
#  'operación douve',
#  '42 sketch 2013',
#  'advent saga digital tactical card game',
#  'man opinion moonlight song collection',
#  'crap amidst hilarity vol 1',
#  'packable fashionable protective ultimate sun hat',
#  'echo fuel echo portable universal charging base',
#  'voxcube 8x8x8 rgb led chainable cube',
#  'new world disorder',
#  'generation fx documentary film',
#  'rack ruin orbit 3',
#  'help prepare upcoming art',
#  'forever rechargeable talk super capacitor flashlight',
#  'covenant',
#  'elephant gun medium blitzkrieg',
#  'shared story afghan diary',
#  'gentle art tutelage',
#  'air bonsai | create little star',
#  'canadian invasion choose adventure album',
#  'wrist cover',
#  'high stake short film',
#  'fomatek foam laptop desks music stand elevate gear',
#  '100 rising',
#  'sky scraper project',
#  'key moon length album',
#  'worrisome wilf beastly bedtime',
#  'airfoil click pen aviation inspired gel rollerball',
#  'vlc new windows 8 user experience metro',
#  'raise fund new jonathangluck wayward kind album',
#  'spider fly',
#  'knock drag',
#  'day dead tyrion lannister calavera vinyl sticker',
#  'harold vs horde',
#  'camille peruto new album',
#  'app custom shoes/ calzado personalizado madame marian',
#  'tye photographic journey',
#  'ropw',
#  'chelsea chronicle podcast',
#  'wildlife inspired t shirts help help wildlife',
#  'sword asumi visual novel',
#  'wax stacks lp record crate',
#  'throw car door dent protector',
#  'strawberry fields café patisserie',
#  'tofu stylish t shirts freedom',
#  'american confines vol 1 cincinnati 52',
#  'good company',
#  'launch romeo juliet yiddish new york city',
#  'case silent girl dark sherlock holmes tale',
#  'chase blue trans theatre festival',
#  'mooli london | designer camera tech bag hampton',
#  'clothing label 90 state mind france',
#  'ultimate custom shark rig',
#  'conference paradigm shift meeting 3',
#  'climb 4 kidz',
#  'tugboat collective inaugural season',
#  'geocaching trading cards history series ii',
#  'fun n easy cookbook children fun cooking',
#  'space trucker',
#  'high',
#  'club wick3d',
#  'modern handmade ceramic paper clay',
#  'join complete solo project cd',
#  'emotional makayla mommy birthday gift',
#  'ashley beauty tool organizer kit',
#  'alaska bug bites llc farmers markets launch',
#  'quick query relaunch',
#  'quick clockwork knight volume 2',
#  'writtenwitheart',
#  'uptown juice company local cold pressed goodness',
#  'strain war playing card',
#  'wood floor fundraiser',
#  'water purification system solar evacuate tube',
#  'steel cathedrals- short poem digital age',
#  'chameleon chronicle color fate',
#  'ghost ephemeral 7-song ep',
#  'chic oneclutch ™',
#  'afraid galileo album',
#  'paterson falls film festival',
#  'spilt milk',
#  'thailand country',
#  'equinox comic genre fantasy',
#  'student operated fabrication lab',
#  'nurse mare foal bear die',
#  'bird nerd',
#  'funky grits fast casual diner pair music menu',
#  'great kentucky goblin spree',
#  'help community building art austin patterson park',
#  'scratch',
#  'pierced heart tattoo boutique start',
#  'pole diversity showcase acrobatic dance',
#  'mckenzie project',
#  'new omni wheel mechanical innovation create robot',
#  'brewstick ~ carboy ruler',
#  'open fiesta arts store dream big san antonio',
#  'opening portal dvd',
#  'night terrors garden limbo',
#  'inclusive toolkit tool ios os x app accessibility',
#  'greek4fun',
#  'hood brewery',
#  'fooju dance collaborative',
#  'chris critelli records debut ep',
#  'piero marsili',
#  'sleep truck',
#  'design leatherjacket',
#  'sanfilippo wing',
#  'road runner multisport smartphone carrier',
#  'lego imagination lab',
#  'arkham source book',
#  'finishing festival funds final stage short film',
#  'lonely house films adam hope',
#  'adult colour debut album',
#  'open a.i.r.',
#  'home maine film series homebirth midwives',
#  'fusionproject',
#  'lego batman zombie genesis series',
#  'digitize family',
#  'progress steampunk series season 2',
#  'winter writing residency',
#  'dome shade sunglass big head',
#  'portrait day 365 challenge',
#  'xpump | turn sound source home theater experience',
#  'complete paine skatepark',
#  'westward 8',
#  'paperback kindle available',
#  'tiba putt personal approach improve putting',
#  'ghost herd rescue horse horse people kentucky',
#  'gideon epic forge',
#  'survyval breakthrough hoodie',
#  'farmer bean holy roast',
#  'jessica rabbit production',
#  'final hour kira kira rainbow unicorn stickers',
#  'belleflower feature film',
#  'mab mindz sound set 2014',
#  'lei',
#  'adaptation wrong',
#  'bicycle bus',
#  '1st cookbook child',
#  'book maxwell',
#  'glory kingdoms guandu core set',
#  'great apple pie',
#  'belong world ackermann repository arts',
#  'seven devils feature film',
#  'chill puck beverage colder long',
#  'heroes stranger fringenyc',
#  'project world',
#  'quadrato retractable knife 100',
#  'single track contemporary art gallery espresso bar',
#  'great fly cup bake',
#  'un amour oublie love forget',
#  'loop resource strategy game tomorrow leader',
#  'contractors create 3d model prop asset model 1',
#  'sasha fashion spectacle',
#  'bass river press',
#  'betul soykan records joaquin turina violin work cd project',
#  'food truck world',
#  'publish occupy portrait',
#  'daweyu hills crop cup',
#  'dream project',
#  'peripheral vision short film',
#  'pimax world 8 k vr headset',
#  '4 oakland',
#  'florida broken kingdom',
#  'help start jacksonville paint pottery store',
#  'baby boom baby bag',
#  'eunoë',
#  'scar tissue',
#  'stagnant pool enter post production',
#  'pro movement',
#  'billion dollar project',
#  'novel',
#  'peak view brewing company',
#  'find black love documentary',
#  'patch organics',
#  'virtual addiction recovery website phone app/ saving life',
#  'fatnek clothing sublimation series t shirt',
#  'titanium whiskey glass epic drinking glass',
#  'child feature length comedy',
#  'college spring break review',
#  'tall tales evening dance choreojoey',
#  'light come',
#  'wood fire oven grow community',
#  'trap 2nd record vinyl release',
#  'rocky horror saved life fan documentary',
#  'song damned jake brock late album',
#  'circa vitae request crowd fundage record length album vinyl',
#  'stiletto red new ep',
#  'bucks county movie',
#  'lazershirts shirt',
#  'country christian album title believe',
#  'color art party',
#  'wholesters- new way whold thing',
#  'stamp',
#  'steer wearable device save life',
#  'ripple analysis bring animation life',
#  'croc2pop kid manage dad digital addiction',
#  'carolina hot',
#  'tulip',
#  'ignis fatuus comic project',
#  'hoodratz',
#  'kingdom space exploration rpg',
#  'leonard hodgins components',
#  'deluxe rpg handbrain screen',
#  'la press soap home 2 minute chemical',
#  'c r o s s t o w n   help finish feature film',
#  'spice whipped beaten culinary works',
#  'grill beer cookbook',
#  'womanhood short film fundraiser',
#  'sunrise diaries',
#  'tommy',
#  'solo exhibition recognise gallery step',
#  'bromotion',
#  'film project   history come',
#  'savage thunderscape',
#  'mc type bad tattoo vol 3',
#  'man island',
#  'completion history kent',
#  'grandkid record length album',
#  'border',
#  'firewater',
#  'annulus ring light',
#  'gospel jazz independant artist cd project',
#  'ugly cartoons poorly draw miserable people',
#  'occupy left forum zine',
#  'dancing classroom grva 2013',
#  'daily bread story rural greece',
#  'monster short film christina morris',
#  'black knight brick build bbq grill',
#  'boat clyde adventure puget sound',
#  'victory record debut ep',
#  'daystay',
#  'league honor',
#  'make bringpack',
#  'projecteo tiny instagram projector',
#  'digital aristocracy commoner guide digital riches',
#  'time',
#  'lazy glamour eco underwear soft sustainable',
#  'saber design apparel',
#  'capture soul town',
#  'soft organic cotton underwear give',
#  'storybox today',
#  'cyberine 1',
#  'poem apostates tale young scientologist',
#  'screening mr turner',
#  'senior project short film home',
#  'treasure trap',
#  'suburban daze',
#  'flyover farm',
#  'focus fan lions tour 2017',
#  'zero dark thirty watch difference',
#  'baby name newborn',
#  'faithful lesbian mormon story',
#  'lazer edge series ebike start $ 499',
#  'intelishake smart sport drink bottle + build storage',
#  'bailey golden retriever calendar',
#  'painting portrait custom painting',
#  'spun monkey dyeworks lounge',
#  'reusable giant coloring poster black',
#  'lux3 wellness lamp',
#  'living puppets novel',
#  'romantic christmas',
#  'project earth monster story bias',
#  'yemanja caribbean restaurant bar hostel',
#  'eucalyptus wear environmental clothing company',
#  'jazz funeral coney island',
#  'self illusion best friend worst enemy ep',
#  'blak woman dynamik reborn',
#  'cause art gallery',
#  'thailandmike no.1 portfolio hiccup tour guide sketchbook',
#  'midwest story',
#  'pentimento documentary rene gimpel',
#  'mike moreno group fall 2011 release',
#  'sansin_band ep',
#  'tale sheepland imagination child',
#  'kindness stranger',
#  'maybe poison',
#  'smart dive buddy smartphone dive camera computer',
#  'final fantasy 8 viii happen',
#  'iphone skin real apple wood',
#  'goalzidia | let reach goal',
#  'mongol art world tour save art',
#  'darling june',
#  'monster mob fun card game monster family',
#  'blacklivesmatter series',
#  'sorensen glass studio',
#  'free supercomputer',
#  'king astronauts documentary',
#  'music fame diva djs t shirt',
#  'æmp dance amiti perry + company',
#  'flutter flow knitting book',
#  'sci fi janitors vs redbull soapbox race',
#  'redemption',
#  'course stunning fantasy rpg gamemaker studio',
#  'secret behavior magazine',
#  'michale graves vagabond acoustic extremely limited edition',
#  'odyssey skateboards launch',
#  'poolpooj',
#  'dark forest',
#  'shoot thrill shoot kill political sculpture',
#  'structure',
#  'money shoot',
#  'vagabond search homeless father',
#  'earthread fabric future',
#  'game quick move steal turn',
#  'amateur prose book poetry story original art',
#  'little boy wonder short film',
#  'judge irreverent party game',
#  'start herb garden',
#  'phantom limbed romantic comedy',
#  'defender realm minion',
#  'matt whistler movie feature film',
#  'undo trilogy',
#  'guardian salus book 1 halix series',
#  'blakes burgers',
#  'build traditional tipi',
#  'legend white woman creek',
#  'develop new worlds hot chilli',
#  'rock audition concert sheri sanders',
#  'fragile stephanie mathias ep',
#  'second scene culture city project',
#  'agrandissement de la brasserie',
#  'far christopher rush story 2',
#  'esquilo simple iot development wifi + web ide + cloud',
#  't bone cherry hog',
#  'random table wiki',
#  'natural face foot body scrub',
#  'lds home teaching app visit teaching',
#  'mother go',
#  'fritz robotic puppet',
#  'casper bad spirits lp funding',
#  'minecraft hungergames',
#  'world fair',
#  'campbell glassworks co.',
#  'zen tek aquaponics- run air',
#  'poem',
#  'burn manc festival',
#  'airlock bike helmet',
#  'lampenschirme und objekte aus französischer handarbeit',
#  'woods',
#  'green lizzie container truly adapt recycling',
#  'well morrissey birthday mix',
#  'ride suicide 2015',
#  '3 mm aluminum pick plectrum',
#  'tara normal',
#  'photoshop illustrator designer',
#  'profound fatigue produce fly deer theater revise',
#  'dungeons heroes',
#  'turn messy arduino project clean design 2 $',
#  'paint entire favela rio de janeiro',
#  'open tank',
#  'reed bringing tablet read speed',
#  'flag world',
#  'mover kit kid move building coding',
#  'volksdangler hack pocket',
#  'p link guitar pickup interchange system',
#  'book bare bones 2',
#  'profitstick | feel power',
#  'mailbox forthcoming album',
#  'rocket ranger reloaded',
#  'write estimate estimate write',
#  'portscenter',
#  'like neighborhood',
#  'sparklab educational build mobile',
#  'karma get face lift',
#  'restaurant go grain colchester essex',
#  'bull dragon pop restaurant project',
#  'torque',
#  'stage stage music theatre',
#  'phochron xa film camera shutter speed tester',
#  'vivian dog moves brooklyn',
#  'darkghost assignment book brothers',
#  'mick life',
#  'free soap start soap maker',
#  'nice set shells~~ handmade seashell jewelry',
#  'shatter restore',
#  'barry county milk',
#  'giant communist',
#  'surf right documentary inspire cold water surfers',
#  'survive treasure island choose path',
#  'talega holiday annual halloween light',
#  'help publish picture kid book',
#  'moon eye view save world',
#  'safe food makeup household product',
#  'geek seeker',
#  'quern undying thought',
#  'nabil karim | anise k ~ bicentenary album',
#  'destroy slackers animated feature film',
#  'seeker aerial video drone',
#  'quikceipt paperless solutions',
#  'splendid entities catalog project',
#  'champion children vol 1 know champ fund',
#  'dragonfly',
#  'ale house string band debut album',
#  'new cornell hurd band cd great new song love',
#  'dodecahedrone rpg post apocalyptic robots d12s',
#  'follow help barney',
#  'da dome roller skating rink brooklyn new york',
#  'tankwork cooperative tank action',
#  'winter mind ep funding',
#  '12 day commision spree 1 custom hand draw art',
#  'charlene kaye make new record animal love',
#  'chefs open shakewell bar kitchen',
#  'lonely himalayas',
#  'phrenic interactive comic alternate reality game',
#  'carnival arts exhibit miami international airport',
#  'unassisted ep revolution',
#  'dead night',
#  'wazupio',
#  'daggermond',
#  'choose fate film put charge',
#  'lock jeans',
#  'dos pueblos tecnicos',
#  'geekholder hold phone tablet laptop screen',
#  'maze slime',
#  'long range murs band gps tracker smartphone communicator',
#  'sins roleplaying game',
#  'cakehouse layer studios comics zine',
#  '1of10 t shirt protest trump putin connection',
#  'doctor menace foonf',
#  'bird eye view 1892 map atlanta 1000 piece puzzle',
#  'prelude conversation',
#  'new social network',
#  'autopsy die man',
#  'art lover place',
#  'bona dea gluten free goodness',
#  'got beat fbi year old',
#  'pony death ride make album',
#  'love animals debut ep project',
#  'unknown arizona',
#  'bridge sighs short film 2',
#  'legendary steamboat springs band record album-- 30 year',
#  'luxury timepiece system minimal everyday watch system',
#  'rest stop restaurant',
#  'maree v. state documentary',
#  'girdy webcomic',
#  'magic tower',
#  'da stooges wipeout surfaris',
#  'lobster art project',
#  'quartz bottle water purification self cleaning bottle',
#  'follow racine east africa safari rally',
#  'sky lounge visual ep',
#  'acnedust ™ organic acne treatment -acne dust sleep powder',
#  'legendary cobo',
#  'philip brittany burton new album fear',
#  'mason ry silicone koozie',
#  'shirt east idaho aquarium',
#  'new lp release shape earth',
#  'rinsekit revolutionary portable shower',
#  'singularity',
#  'taluva deluxe version',
#  'calvin thomas make october sky album',
#  'wilmer wilson iv summer art residency nls',
#  'gladys sing',
#  '2012 lake george music festival',
#  'seek shelter vol 3 rescue animal ho',
#  'boutique disco flash québec',
#  'fail safe project length album',
#  'door feature film finishing fund',
#  'decorative oxygen tank bags amarijade inc.',
#  'commit suicide',
#  'scarf cuff',
#  'behold uprising ep',
#  'johnny strange',
#  'panini company',
#  'legendary warriors productions',
#  'statue doc u.s.marines corpsman',
#  'stagecoach mary',
#  'knot app',
#  'powerbark-"meal run dog',
#  'tenacious exclusive scott tolleson uncle argh noir mini qee',
#  'centennial armenian genocide t shirt',
#  'mini flashlight fire starter',
#  'big inside',
#  'jordon bould butcher blocks',
#  '',
#  'somo mixtape',
#  'little women graphic novel project',
#  'joy ike record 3rd length album let',
#  'lotus earring',
#  'adults',
#  'bohemian book project',
#  'viking hood alive kick',
#  'tenor journey german land',
#  'vanilley bean treats life sweet moment',
#  'wheeling careen wander emp',
#  'fireball newsflash crosswords 2015 16',
#  'kung fu bellydance masters',
#  'academia de música impulsarte.org',
#  'world year',
#  'living coaster beverage coaster grow plant',
#  'naturalia young adult book surprise girlfriend',
#  'chop sooey charm pin',
#  'wheelhouse farm table restaurant st joseph il',
#  'galaxy trian new order',
#  'air air ~ portable air quality detector',
#  'conduit sports dynamic bone conducting headphone',
#  '',
#  'tableau vivant delirium constructions global tour',
#  'seth pineapple mango salsa',
#  'day x',
#  'day time 365 day photograph',
#  'free world brand clothing co.',
#  'planet hell post apocalyptic web series',
#  'little falcon need help',
#  'customizable 3d printed miniatures',
#  'short defender ©',
#  'heya toothbrush holder simple clean bacteria away',
#  'imminent',
#  'love tongue death eye',
#  'pocket parking meter',
#  'mechabrick minifig mecha board game model',
#  'cat cafe mad coffee shop remodel expansion real food',
#  'pollock l’acchiappa panzane',
#  'unconditional hope   survivors story',
#  'finish amish appeal',
#  'gamerline clothing starter business need help',
#  'sports city',
#  'vyu360 ™ 4 k procam',
#  'justifier',
#  'sinner iii supernatural horror comic night motel',
#  'ez master double boiler attachment stand mixer',
#  'shakespeare fund fund question',
#  'monkey paw',
#  'charlie vs goliath',
#  'new madysin hatter ep title pretty little fool',
#  'release black heart album',
#  'bad day blue',
#  'pappino dein foto auf einem recyceltem kartonrahmen',
#  'coach life times shawn tompkins',
#  'life online',
#  'promise tempus film',
#  'grace gentle playing cards lunzi',
#  'kingdom angelic war card game',
#  'april alayne studio',
#  'ultra way cool teaching puppet',
#  'chain mail creation',
#  '3d film perfect divorce',
#  'average grill cheese',
#  'supplicant age dissidence',
#  'diarios de viaje película',
#  'alé garza h.a.r.d.core',
#  'kind mind wise souls launch collection',
#  'bring seattle geekly podcast',
#  'galactic princess',
#  'la feria concreta documentary film installation',
#  'debut original album mindy stratton',
#  'night_rider',
#  'xybear heroes',
#  'archive warhood odyssey',
#  'vaudezilla chicago burlesque coloring book matt hansel',
#  'homestyle video installation delicious spectacle',
#  '4 color press 5th street garment company',
#  'maltese brewing company',
#  'hollow',
#  'perfect plan',
#  'dionysius games indy games',
#  'music production',
#  'markus mann music cd production tour',
#  'tropical bat house',
#  'wade water gallery',
#  'woodland banners poetry walk',
#  'soul 2nd ep record',
#  'home jug decal t shirt trophy tailgate',
#  'battle orion 2',
#  'pretty ugly awp',
#  'homebound film transform image latinos',
#  'nepenthe short film',
#  'jesus homeless woman clay bronze',
#  'audio heroin chic cyber doll',
#  'self produce debut album',
#  'bizarre case globular gullet',
#  'earth wall ii rammed earth sculpture',
#  'boys bow tie tour',
#  'inches short film',
#  'teslatronix- tesla power masse',
#  'wood gift personal memory',
#  'inspire x sound',
#  'pastor damien season',
#  'speculative relationship sci fi romance comics anthology',
#  'veteran art david geig',
#  'marketplace crowdfunded product',
#  'note self',
#  'orillia summer theatre 2016',
#  'maria sweet sing',
#  'aurora chronicles hero',
#  'aj handmade style',
#  'kickstart art',
#  'paladin warrior charlemagne',
#  'john lennon peace chance book',
#  'jessica jewelry',
#  'creative community',
#  'green light radio broadcast arise festival 2014',
#  'poetry safe new good reading film',
#  '1 man 10 day 100 + canvas',
#  'bt block tower',
#  'versa tool',
#  'dreamafrica',
#  'failure jacket',
#  'dayz come + = new worship project',
#  'healthy sustainable clothing',
#  'new york travel sightseeing video blog',
#  'magpi magazine virtual reality',
#  'loquat arsonist short film music video',
#  'unique collage',
#  'corey coffee bar',
#  'inhale sunrise',
#  'son odin fantasy football',
#  'chimera station euro edition',
#  'ghetto love write weedie',
#  'ping 2 attack sphere wii u ps3 steam',
#  'loud bicycle car horn bike',
#  'vince durden world eco friendly backpack',
#  '2000 mile',
#  'black mint playing cards',
#  'holiday experience 2014 jazzy christmas celebration',
#  'renwick ally album ryan angell aka andrew juco',
#  'amphibious red couch',
#  'rabbitwild shelter wilderness',
#  'leah stein dance company 10th anniversary concert',
#  'parthia saffron door thread time',
#  'upcycled planter',
#  'youth education tv talk',
#  'mango pineapple habanero toe curling hot lava sauce',
#  'epic backpacking dynasty global millennial revolution',
#  'ainsley band uk tour',
#  'fantuckfastic onesie',
#  'iwish sigil magic',
#  'mars transit game funspace circle friends bo regard',
#  'self sufficient water filtration system kind',
#  'sawyer dinosaur child book',
#  'magician cat print edition ebook',
#  'berwyn project ep mc type thewoods',
#  'undive dark sea 500 m',
#  'iviou future buy sell online',
#  'rustic reclaimed furniture 100 hand',
#  'lonesome days 1st studio album',
#  'league legends cosplay',
#  'lose like human 2017',
#  'animal playing card',
#  'entertain photobook lois golding',
#  'see swiss picture people world engineering',
#  'love gut high school',
#  'cafe gangster',
#  'rivers monroe fall tour 2016',
#  'golf alpha yankee lgbt human rights documentary',
#  'colombian art gallery la magic realism strike',
#  'turn',
#  'animal masks 10 week',
#  'dancer descend mount kenya memoir',
#  'press start bar',
#  'zombme',
#  't shirt design startup',
#  'zisil',
#  'faceless neil',
#  'starbird land earth debut album time',
#  'bryan wilton print audio',
#  'downtown mural',
#  'zombie usb keychain zed 1.0',
#  'skullgarden linocut print project',
#  'soundtrack story dj',
#  'sweet surrender',
#  'alaina blair cd tour project',
#  'cemetery angels photographic book',
#  'sledge leather reply to(insert large ass metal label',
#  'kensaku shinohara mana spring 2014',
#  'help exhibit art geordanna artist',
#  'exoskeleton assault squad hura technocracy 15 mm sci fi',
#  'moar online multiplayer fighting game',
#  'esperanza gang intervention photo documentary',
#  'jakten på makten brädspelet om svensk politik 2016',
#  'create liberal america',
#  'cook fire disaster cookbook',
#  'violet tendencies star mindy cohn dvd',
#  'disgruntled deck original card game veteran',
#  'come sea ambitious short film',
#  'elemental burn city',
#  'sol mcnally photography',
#  '45 led packlight let bend light need',
#  'flowpaw learn computer code build gizmo',
#  'home ground',
#  'pixel press draw video game',
#  'sexy action accounting myths short film',
#  'moment iphone 7 well camera',
#  'poetry',
#  'post election student voices hope resistance',
#  'ion music detect mood light bluetooth low energy',
#  'bring patrizi family food truck experience',
#  'musical help trouble number',
#  'fuse defiance album 2015',
#  'mobile drool central',
#  'awfully sudden album',
#  'parallel print edition run come age novel',
#  'want apply x factor music project',
#  'beat track',
#  'lovers lose feature film',
#  'coon age volume',
#  'live dorothy parker hollywood fringe',
#  'traditional astrophotography window cygnus',
#  'hole wall hector records debut studio album',
#  'lighten',
#  'surrender spirit creative writing project phase 1',
#  'newton wildlife adventures',
#  'secret tomato project',
#  'xstink',
#  'open online gallery great dinosaur art artist',
#  'meditation 8 simple technique beginner',
#  'qi aerista ultimate wi fi enabled smart tea maker',
#  'art mitch foust 2017 yearbook',
#  'bring victorian life',
#  'chat choice gaming',
#  'thank letters krys',
#  'margoh make legend drink london style',
#  'original painting £ 10',
#  'opuntia',
#  'debut hip hop album mikelwj',
#  'shattered shards 3d printable fantasy war games scenery',
#  'temple flower | vibrant activewear yoga apparel',
#  'scorn star american idol alum 2x grammy nominee chip',
#  'project',
#  'maori mbt awareness centre',
#  'weekly video series',
#  'bike pouch',
#  'global intersection 13 world materials method',
#  'zombie t shirts hoodies',
#  'alwaysremembered.com new way remember love one',
#  'moustache bow tie project mo bros mo sistas',
#  'official music video single forever',
#  'prelude psychological survival horror game',
#  'bible app',
#  'een leven lang flow',
#  'garment collective ethically source redemptively',
#  'beginning mark barnes',
#  'challis effect heart build graveyard',
#  'log',
#  'maui maine 2017 | claybourne tour',
#  'worlds adventure fantasy realms',
#  'perfect boots fernando berlin',
#  'dihydrogen monoxide conspiracy',
#  '3d survival kit',
#  'ton music buck',
#  'adoree european promo tour summer 2011',
#  'read bible 1 year card system',
#  'rob wiley custom leatherwork',
#  'n3on love official launch',
#  'littlerp affordable flexible open 3d resin printer',
#  'fallen guardian angels film project',
#  'monocrane reversible leather book bag photochromic ink',
#  'hilarious film call mooo',
#  'hi help publish wizard legacy',
#  'bondurant brothers distillery',
#  'summer goth 2016 finish fund',
#  '',
#  'duo diy twin lens reflex camera instant film',
#  'western sydney arts academy',
#  'pursu passion career',
#  'crazy train',
#  '1862 railway mania eastern counties',
#  'life',
#  'pongcaddie save ball beer pong nets',
#  'julia fanning debut ep',
#  'sprite lamp dynamic lighting 2d art',
#  'z day lena pendleton',
#  'road italy',
#  'immersive cinema',
#  'bbq dragon barbecue fire supercharger',
#  'dineamics',
#  'unearthing',
#  'uncle samta final hour',
#  'know like',
#  'igloo glass world cool beer glass',
#  'treasure book cover',
#  'come sweat',
#  'finish el toro tot food trailer',
#  'madjacks | ski pain free | walk normally | affordably',
#  'phil king leeland',
#  'elbow knees cripple crush ep',
#  'broadway come denver scholarship fund',
#  'bedroom behavior lingerie',
#  'love libya',
#  'amazing tales wasted lands inaugural issue pre sale',
#  'geex season',
#  'old soul lion',
#  'sleep board',
#  'kevin woody solo album',
#  'norman einstein normanthology',
#  'donate money music video shoot september',
#  'kronos pino family ranch',
#  'stolen crystals',
#  'low shoulders short film',
#  'endless whispers cycle featurettes',
#  'dexter etsy shop expansion',
#  'inflatable jake band t shirt',
#  'artisan vinegar',
#  'saga splintered realm',
#  'coolrunnings physical release reality',
#  '51st studios unplugged wood headphones feature bluetooth',
#  'film',
#  'edgar wallace jr. get saxy studio new c.d.',
#  'cirsova 2017 s 5 6 lovecraft swords space ships',
#  'lego chess set',
#  'feed fingers double album',
#  'telemetry webisode',
#  'song word',
#  'chris custom build pc',
#  'record ben cyllus new project',
#  'motion present moments define nyc',
#  'letter basic training',
#  'major factor',
#  'watch inspire life',
#  'affordable computer controlled quilting system add',
#  'manboy lp oliver manning',
#  'reds.box privacy cloud',
#  'odyssey homer amazing youth actors giant puppets',
#  'namm marketing -keepe big dog',
#  'debut ep album promotion',
#  'doodle creatively interactive children book',
#  'ninjutsu pencil holder',
#  'bocusini world plug play 3d food printing system',
#  'conservative theatre festival columbus oh 1/7/17',
#  'spread love',
#  'run fast',
#  'aivot',
#  'fashionrider tell video documentary',
#  'shred pro rider snowboard game',
#  'riddle sphinx',
#  'weekend love',
#  'los angeles women theatre festival 24th anniversary',
#  'gender neutral pair dance explore gender role dance',
#  'illusion reality',
#  'daniel ordinary tragedy new musical',
#  'glass paradise',
#  'genesis collection',
#  'attention life extreme',
#  'covalence molecule building game',
#  'professor vogel alternative history machine i&a issue iii',
#  'monadnock gymnastics',
#  'banaau get level',
#  'solo art miami',
#  'cinema verde',
#  'douse sauce story',
#  'king guild',
#  'nostalgic restoration youth',
#  'beast spearpointe book 1 10 new epic fantasy series',
#  'napa valley private label wine',
#  'human want sf anthology',
#  'ian mahan new album little moment',
#  'gbs detroit present daniel harrison $ 2 highway',
#  'pot coffee',
#  'pet beds',
#  'paprika short film',
#  'dark shade fado',
#  'life career change dream camera goal',
#  'lightbulb terrarium hand mini terrarium',
#  'dead burger abomination films',
#  ...]

# %% [markdown]
# # Using NLTK and LSTM

# %% [markdown]
#  Approach to the problem:
#
#  - We will one_hot to get the indices of words
#  - We will be using padding to make input all the same length
#  - We will passing the input to to Embedded layer than to LSTM

# %%
voc_size = 10000
sent_length = 12

# %%
# One hot rep
one_hot_rep = [one_hot(words, voc_size) for words in corpus]
one_hot_rep
# Out:
# [[910, 9489, 9986],
#  [1344, 7672, 5775, 8602, 4814, 9293],
#  [5983],
#  [5858, 7125, 6447, 4687, 6199, 4483],
#  [1073, 4828, 5642],
#  [8431, 1707, 4987, 3655, 4253, 1147, 8250, 1306],
#  [952, 7591, 7591, 4515, 404, 7519, 7651],
#  [5370, 3004],
#  [564, 4272, 5493, 7307],
#  [5270, 6153],
#  [1550, 1420, 4132, 2749, 9761, 2086, 4013, 3679],
#  [2823, 7263, 3825, 6175, 3267, 9699, 4796],
#  [894, 5366],
#  [3042],
#  [2174, 4967],
#  [3938, 6889, 8340, 8133, 4483],
#  [3151, 4074],
#  [4738, 2374, 4519, 2406, 4797, 3231],
#  [3842, 39, 9765, 5238],
#  [6111, 7793, 1550, 4608],
#  [3115, 7091, 7364, 5432, 5197],
#  [769, 5316, 3871, 6480],
#  [948, 6609, 5251, 9824, 4515, 9772, 4483],
#  [9691, 1609, 8502],
#  [8301, 1310],
#  [662, 8879, 8065, 8512, 6047, 4398, 3363],
#  [9202, 1561, 4504, 3947],
#  [2593, 7091, 3655],
#  [3127, 8490, 7794, 7644, 7919],
#  [4075, 4194, 8572, 9487, 1713, 1651],
#  [150],
#  [5986, 778, 1650, 5493, 4241, 7781],
#  [4808, 4191],
#  [5974, 5899, 599, 4483],
#  [7280, 26, 3947, 7280, 6462, 9200, 26],
#  [4388, 6996, 5501],
#  [4687, 7380, 3437, 4515, 5493, 7781],
#  [9749, 1477, 8013, 3960, 5107, 5873],
#  [4330, 769, 1148],
#  [5533, 8679, 9049, 5193, 3267, 2736, 6110, 7787],
#  [6720, 6720, 6296, 463],
#  [7794, 5157, 5107, 5493, 7063],
#  [851, 5170, 4519],
#  [255, 4366],
#  [6549, 449],
#  [5162, 9731, 3584],
#  [3715, 5117, 8253, 6785, 3947],
#  [4014, 862, 4178],
#  [1310, 135, 6878, 4151, 4939, 5185, 4825],
#  [2691, 1054, 7817],
#  [313, 5945, 8174, 8530, 3880, 7916, 8454],
#  [5127, 1665, 2834, 8892],
#  [925, 4380, 5478],
#  [862],
#  [4230, 9613, 2986],
#  [9731, 6549],
#  [2691, 7382],
#  [5040, 5120, 1450, 5540, 4910, 6765, 2374],
#  [9677, 2828, 416],
#  [5354, 7276],
#  [8072, 2577],
#  [128, 2634],
#  [6588, 1012, 8174, 8857, 4078],
#  [5630, 7361, 4621],
#  [6335, 7291, 7273, 5771, 3039, 4920],
#  [7765, 80, 3129, 2353, 1718],
#  [5532, 9296, 599, 7307, 7148, 6881],
#  [8743, 9190, 8407, 3773],
#  [2821, 2473, 9471],
#  [4806, 4678],
#  [6751, 1763, 1370, 7794],
#  [9722, 8711, 1797, 898, 3212, 9591, 3267],
#  [2064, 3042],
#  [3158, 696, 9970, 4218, 8229, 5193, 3267],
#  [2858, 5274],
#  [6875, 6660, 9445, 1404],
#  [2700, 5705],
#  [2634, 3696],
#  [5570, 3099, 6445, 7259, 7356],
#  [54, 1148, 3547, 1114, 5240],
#  [3655, 7380],
#  [4462, 1454, 8794, 5107, 412, 45, 2458],
#  [9701, 7451, 701, 2219, 3212],
#  [7531, 2899, 6480, 1141, 3696],
#  [3565, 2989, 9238, 9658, 3282],
#  [1028, 2633, 1148],
#  [4922, 1125, 789, 3115, 3947, 3762],
#  [3466, 5850, 5407],
#  [1902, 7807],
#  [3106, 5180, 7276, 6732, 493],
#  [5493, 1853],
#  [2809, 460, 7745, 1370],
#  [6787, 9496, 2341, 3675],
#  [169, 2499, 9725],
#  [4856, 8138, 7276, 3172],
#  [3740, 4207, 4953, 8947],
#  [8177, 4283, 4905, 8892, 9507, 8528, 7461, 8115, 4504],
#  [9446, 7714, 2749, 9238, 6785],
#  [7356, 7516],
#  [759, 9174, 8899],
#  [5732, 2039, 700, 1148, 4483],
#  [5774, 3700, 4095, 3267],
#  [3934, 6158, 797, 6794, 830, 1466],
#  [9078, 2293],
#  [4736, 3270, 5107, 9718, 6343, 5493, 4483, 6480, 769, 3947],
#  [9626, 1926, 6823, 7531],
#  [480],
#  [4324, 797],
#  [3406, 3154, 672],
#  [1498, 9152],
#  [1616, 2660, 6047, 8329, 894, 2828],
#  [5909, 1613, 2893, 2244, 1225, 349, 3459],
#  [1159, 12, 3249, 1135],
#  [9387, 4117, 2274, 9018, 1196, 6884],
#  [8520, 5583, 7916, 5583, 6052, 8682, 4216],
#  [3352, 2406, 6483],
#  [3921, 4515, 7696],
#  [2356, 4687, 6733, 9472, 3558, 8880, 5605],
#  [4687, 4825, 2989, 6442, 6768, 4740, 7372, 5197],
#  [8342, 5815],
#  [7794, 4869, 8813, 9627],
#  [918, 9950, 195, 9642, 973],
#  [5209, 3788, 4400, 5493, 910, 9496, 2043, 12, 7476, 5613],
#  [1883, 3126, 9539, 9405, 6102, 4241],
#  [2500, 5986, 9464, 5330],
#  [9312, 2776, 6491, 5902],
#  [8855, 2660, 8488, 8859, 3267, 1021, 4750],
#  [8493, 9711],
#  [7340, 4504, 6047, 1262, 2828, 9200],
#  [864, 7544, 255, 7400],
#  [8004, 1159],
#  [781, 4504, 3947],
#  [1148, 6733, 7479],
#  [5461, 6769, 4181],
#  [803, 9602, 3584],
#  [4078, 8133, 4418],
#  [8535, 3215],
#  [6400, 6929, 6806, 5185, 769, 2639, 1227, 8582, 2056],
#  [6828, 255, 7841, 9718, 1356, 4483],
#  [4078, 7308, 6107, 4078],
#  [1893, 1484],
#  [7491, 6266, 5348, 340, 7491, 7586],
#  [7007, 3196],
#  [8592, 3051, 38, 8362],
#  [6584, 4332, 6492, 7714, 2612, 849],
#  [5251, 7765, 2776, 4347, 1054],
#  [3451, 6604],
#  [2484, 4151, 8367],
#  [8161],
#  [3651, 2922, 7685, 8229, 5193, 3267],
#  [7794, 6604, 7391, 2191, 910, 5631],
#  [7591, 3048, 3679, 8335],
#  [4052, 8705, 2245, 6247, 2347, 8841],
#  [2168, 4613, 4515, 2168, 759, 5789, 7801, 2650],
#  [602, 9912, 9912, 700, 197, 5835, 1528],
#  [5493, 6266, 9582],
#  [5520, 6211, 195, 3947],
#  [3692, 2550, 3251],
#  [4687, 8340, 1902, 8602, 7745],
#  [4216, 5905, 5446, 4251, 487, 3260],
#  [2405],
#  [1585, 5332, 4177, 7144],
#  [7049, 6047, 1880, 2099],
#  [2892, 8602, 1258],
#  [1461, 2678, 3008, 3565, 255],
#  [7620, 3200, 2174, 9591, 4483],
#  [9090, 1369],
#  [1774, 8494, 4504, 3947],
#  [8703, 2296, 959, 848, 5107, 2986, 2016, 1866],
#  [6828],
#  [7382, 6199, 1148],
#  [7349, 9202, 3231, 1527, 1979, 4483],
#  [5337, 3482, 432, 6009],
#  [8765, 4519, 2040, 6667, 8184, 7733, 7037],
#  [9419, 5493, 846, 5359, 5670, 4532],
#  [9190, 6275, 5493, 9969, 1677, 8189, 4483],
#  [3743, 9487],
#  [2737, 9499],
#  [4671, 719, 5557, 5582, 2929, 4541, 9708],
#  [702, 2899, 9563],
#  [3198, 3130, 5493, 4483],
#  [2632, 1850, 2374, 58, 5272, 6878, 5686],
#  [3669, 2855, 3861],
#  [2547],
#  [1664, 6553, 9725],
#  [3329, 8184, 5705, 4687, 4687, 3329],
#  [7956, 4131, 5311, 5478],
#  [5088, 7548, 7666, 7781, 6665],
#  [8242, 463, 9177, 8745, 2003],
#  [7139, 8476, 7946, 6552],
#  [8746, 2845, 5705, 4151, 7467],
#  [3456, 4189, 8335, 4272],
#  [9301, 7919],
#  [680, 7574, 9092, 5946, 5493, 761, 5477],
#  [5909, 6132, 1902, 1028, 857, 438, 7461],
#  [8433, 3559, 2910, 3282, 3762],
#  [7148, 4967, 3912, 489, 998, 3749, 5099],
#  [39, 2294, 367, 1295, 4151, 7483],
#  [6247, 1850, 2666, 2148],
#  [4366, 3915, 8946, 4121],
#  [9299, 1234],
#  [7133, 5521, 4617, 1370],
#  [3168, 4962, 5193, 6120, 2639, 1708],
#  [2736, 4151, 1863, 8947, 3270, 2968, 2736, 8765],
#  [3845, 2978],
#  [1774],
#  [878, 2807],
#  [7935, 4245, 3065, 5692, 236],
#  [1708, 9611, 3231, 5949, 1148, 7307],
#  [6241, 4489, 1284, 1349, 2174],
#  [8767, 6854, 7624, 5764, 2916],
#  [8942, 6708, 4962, 8133, 8855, 6153, 680],
#  [4227, 4653, 1037],
#  [4227, 5504, 4873, 3261],
#  [9633],
#  [8683, 6916, 7919, 2700, 4596, 8834, 5378],
#  [3091, 9970, 9049, 5193],
#  [4825, 9409, 5238],
#  [2633, 7298, 5353, 8054, 1707, 4733, 4186],
#  [186, 841, 4504, 9200, 7685, 1021],
#  [9483, 6553, 2567, 6144],
#  [2141, 9693, 910, 9496],
#  [1442, 2441, 4790],
#  [6248, 6316, 4483],
#  [415, 7842, 3947, 3762],
#  [830, 8879],
#  [9339, 7037, 2431],
#  [6854, 3231, 6480, 5958, 2219],
#  [3115, 8785, 7599, 6052],
#  [5712, 2165, 7654, 9152, 2407],
#  [5259, 165],
#  [5564, 8837, 588, 2562, 288, 2414, 5107, 9816],
#  [2816, 2286, 9127, 4595],
#  [4687, 2585, 3788, 2798, 8602, 7887, 3544, 9507],
#  [4151, 3756],
#  [8343, 3051, 6090, 3002, 2776],
#  [5282, 600, 2583, 7968, 6444, 5732, 3547],
#  [2019, 1148],
#  [5493, 2434, 4818, 8612, 1623, 7498, 4882],
#  [6639, 370, 2441],
#  [8668, 1521, 8602, 7794, 1297, 3696, 6344, 1821],
#  [6003, 4785, 3880],
#  [1479, 655, 2645, 9147],
#  [9953, 6791, 7624, 2964, 6578, 9912, 2632, 9517],
#  [220, 2736],
#  [1880, 4868],
#  [1410, 6444, 5955],
#  [5986, 2570, 7781, 599, 9496],
#  [3233, 194],
#  [325, 4216],
#  [6769, 1687],
#  [5293, 8915, 2059],
#  [2858, 4008, 1013, 5464, 8763],
#  [9160, 160, 6052],
#  [3535, 9321, 769],
#  [4687, 3762, 6275, 4431, 7308, 4504, 3947],
#  [6269, 6873, 3947, 6916, 2016],
#  [9058, 9913, 599, 4483],
#  [8668, 5571],
#  [2634, 2739, 3947, 2639, 8510, 8441],
#  [7672],
#  [9160, 4672, 8784, 7852, 2639],
#  [4410, 7787],
#  [4920, 3867, 2639, 1370],
#  [368, 8685, 6986],
#  [1441, 9563, 5649, 3696, 2418],
#  [4178, 4671, 3136],
#  [9479, 341, 5899, 9321, 2634, 5311, 5670],
#  [6199, 7230, 7413],
#  [4828],
#  [4594, 3330, 7940, 4575, 5073, 3212],
#  [1002, 7407, 4632, 7115, 1432, 2655],
#  [2141, 4195, 6013, 2640, 2640, 3129, 2286],
#  [1645, 6890, 1061],
#  [2501, 5374, 601],
#  [8855, 2479, 748, 9933],
#  [7430, 1347, 1012],
#  [4431, 7335, 6657, 6657, 1132, 8201, 9960],
#  [5998, 6785, 3947],
#  [9598, 4884, 5899, 3],
#  [7896],
#  [4575, 2184, 9167, 8542, 6121],
#  [8452, 8970],
#  [9772, 8947, 3270],
#  [769, 8463],
#  [6580, 4750, 768, 1841, 4464, 3],
#  [2816, 6791, 2546],
#  [1741, 6266, 4304, 7702, 3370],
#  [8493, 2141, 6785, 3947],
#  [6406, 8331, 7948, 9806, 4517, 68],
#  [3904, 1232, 928],
#  [1148, 6266],
#  [9472, 8166, 3473, 4515],
#  [9358, 4724, 6191, 8602, 33, 4828, 5642],
#  [2816, 9487, 6700, 3962],
#  [1147, 5186, 1996, 2828, 5991],
#  [764, 9118, 879, 3267, 8879, 1651],
#  [9178, 3008, 9630, 1218, 4436, 9630],
#  [5315, 5040, 7745, 4564],
#  [8596, 7945, 830],
#  [1497, 6583, 7781, 5788, 7645, 1103, 1123, 7307, 1148],
#  [8682, 4216, 6266],
#  [7205, 506, 4178],
#  [3806, 8609, 9536, 6700],
#  [5117, 1148],
#  [2746, 3681, 4504, 3947],
#  [8269, 6266, 3231, 6088, 1214, 7815],
#  [7107],
#  [1857, 9345, 768],
#  [4687, 2776, 6517, 3231, 6509, 7831, 7794],
#  [8454, 5891, 8454, 3749],
#  [3642],
#  [9740, 4122],
#  [2506, 191, 2808, 3558, 1012],
#  [3679, 6806],
#  [7838, 3566, 1148],
#  [5478],
#  [1246, 9613, 1130, 7919],
#  [1086, 9194, 2828, 195],
#  [5573, 3609],
#  [1741, 6983, 7725, 4181, 6669, 2632, 2814, 2406],
#  [1642, 39, 3709, 2639, 5705],
#  [4856, 1127, 1664, 6890, 9743, 1664],
#  [3270, 6785, 1979, 5185],
#  [3727, 4273, 1225, 761],
#  [2676, 7461, 8662, 6444, 7680],
#  [8133, 3909],
#  [4825, 6313, 4852, 8650, 3788],
#  [5522, 727, 7781, 4541, 7639],
#  [9062, 9238, 9690, 2406, 8906, 195],
#  [910, 4339, 9117, 223, 3589, 4483],
#  [5992, 2097, 7670, 1986, 8305, 7781, 1527, 1979, 4483, 4541],
#  [5278, 2906, 5493, 9496],
#  [2491, 4795, 3425],
#  [226, 2809, 5705],
#  [7037, 9746, 4483, 8031, 4287],
#  [2567, 8602, 7714],
#  [8332, 5493, 4702, 349, 9345],
#  [6798],
#  [7773, 7889, 8095, 3546, 2406],
#  [942, 7825, 2173, 7941, 2406],
#  [5281, 7745, 1882, 9962, 5691, 7685, 6983],
#  [7223, 5098],
#  [7472],
#  [1487, 3070, 6480, 1148],
#  [2479],
#  [768, 3845, 8217, 3212],
#  [3752, 206, 1417],
#  [6047, 3212, 501, 2663],
#  [7524, 830, 4515, 9981, 2634, 9825, 5483],
#  [8659, 5571, 9941, 4151, 4687, 6733, 775, 6785, 3947],
#  [9386, 9043, 6899, 6299, 1123],
#  [54, 7362, 8947],
#  [1948, 4504, 3947, 5238],
#  [3257, 2099],
#  [1997],
#  [3231, 5949, 9772, 2565, 33, 2039, 1604, 9088],
#  [823],
#  [3947, 1148, 6120, 6500],
#  [2067, 5086],
#  [6414, 9062, 8177, 6090, 8335],
#  [6604, 2939],
#  [9963, 6120, 2766],
#  [5119, 7781, 1527, 1979, 4483],
#  [577],
#  [5435],
#  [326, 5366, 8133],
#  [6750, 7148, 1229, 9718, 7307, 1148],
#  [4322, 7486, 210, 5927, 7037, 3129],
#  [506, 976, 8036, 7555],
#  [6475, 2690, 5333],
#  [2593, 8125, 6047, 3327, 4721],
#  [9273, 4504, 3947, 3786, 8672],
#  [9194, 4873, 5995, 7036, 5112, 2966],
#  [4393, 1941, 9591, 983, 5899],
#  [9765, 7802, 1404, 599, 9496],
#  [7101],
#  [1970, 8269],
#  [1207, 1299],
#  [6531, 414, 2698, 7714],
#  [7685, 7890, 3884, 4590, 7685, 6466],
#  [6620, 8022],
#  [1746, 5800, 6403, 6864, 966, 8292, 6733, 4151],
#  [3988, 6769, 1526],
#  [4093, 323, 8051],
#  [966, 3609, 84, 6864, 551, 2184],
#  [1379, 4515, 6559],
#  [7251],
#  [9200, 9650, 7461, 9561, 8748],
#  [6265, 3713, 9555],
#  [6088, 1148, 4504, 3947, 2634],
#  [6369, 5258],
#  [5620, 7519],
#  [9079, 8859],
#  [4333, 8906, 7653, 672],
#  [5824, 1028, 6127, 3953, 4515, 4535],
#  [8454, 1764, 1764, 627],
#  [5795, 3428, 5981, 6047],
#  [7963, 9339, 2639, 3238, 1944],
#  [2598, 6492, 4480, 7683, 7276, 7036, 605],
#  [1550, 8950, 2668, 8004],
#  [8813, 6114, 1850, 8813],
#  [9072, 2349, 2979, 4472],
#  [6934, 7735, 337, 7738, 9194],
#  [1964, 4258, 6396],
#  [5945, 5488, 5478],
#  [547, 7780],
#  [1148, 7672, 4380, 6733, 9273, 6047, 7099],
#  [5013, 4357, 719, 5642, 4645],
#  [6216, 1450, 8738, 39, 7919],
#  [7148, 5760, 1159, 2939],
#  [9327, 6261, 3106, 5501, 9268, 3459, 9496],
#  [4542, 3398, 9148, 8323],
#  [7903, 8602, 33],
#  [2521, 9704, 6463, 672, 4590, 5330],
#  [8477, 2431, 6047],
#  [3058, 195, 4197, 1653],
#  [3938, 2495, 8403, 7842, 7639],
#  [693, 1650, 9496],
#  [7461, 3563, 160, 3270],
#  [8732, 1232],
#  [309, 4669],
#  [6492, 8049, 4022, 5464, 8049, 489, 4824],
#  [4431, 2219, 1839, 491, 2039],
#  [2244, 1706, 4151, 2851, 6791, 4825],
#  [2305, 661, 408, 5580, 3531],
#  [2166, 8602, 6266, 672, 3546, 8602],
#  [2852, 1740],
#  [9273, 3666, 2736, 5193, 3267, 9273, 7787],
#  [7813, 2639],
#  [8754, 1664, 6296],
#  [9690, 2131],
#  [3328, 4346, 195],
#  [5107, 2952, 8421, 2646, 5705],
#  [5551, 6444, 3703, 3527, 7919],
#  [1171, 7523, 8768, 769],
#  [4849, 1153, 78, 2899, 6690, 9788, 9805],
#  [694],
#  [4091, 4515, 4995, 2219, 3212, 4073, 6296],
#  [6122, 3849, 6593],
#  [1096, 861, 1004, 2512, 8593, 7199, 1470],
#  [7815, 5185, 680],
#  [6855],
#  [1028, 7722],
#  [1611, 4131, 1611, 5713, 9864, 4759],
#  [1791],
#  [459, 404],
#  [1004, 713, 8175, 5089],
#  [3504, 2095, 5532],
#  [2507, 3267, 4227, 8022, 2804, 341],
#  [3509, 114, 769, 2095, 6047, 6991, 8602],
#  [3565, 7976, 9181, 4504, 3947],
#  [440, 1466, 7714, 3267],
#  [1944, 8054, 2645],
#  [9412, 6765, 547, 5185],
#  [5261, 2563, 3674],
#  [948, 4553, 3425, 6785, 3947],
#  [4711, 7698],
#  [7493, 7133, 769, 8855, 2639],
#  [7171, 7643],
#  [6709, 3550, 5069],
#  [2681, 2741, 3398, 2426],
#  [8100, 5493, 6266, 5098, 2726],
#  [2346, 4374, 8388, 5319, 4269],
#  [9889, 7741, 6968, 3231, 9496],
#  [3215, 778, 1338, 5477, 1148],
#  [7002, 4117, 7524, 4269],
#  [4013, 2062, 9871, 5150, 6047],
#  [9385, 6794, 467, 2608, 6218, 4311, 7626, 7395],
#  [1206, 5337, 6425],
#  [1121, 6264, 6051],
#  [5029, 5773, 4797, 6376, 4212],
#  [9481, 2634, 923, 2632, 6301, 923],
#  [313, 38],
#  [9286, 3655, 5488],
#  [5616, 8177, 8342, 7666, 5280],
#  [6402, 5618],
#  [6266, 7432],
#  [9363, 8164, 1306],
#  [7280, 7417, 3915, 612, 1461],
#  [9200],
#  [599, 5352, 3762],
#  [3311, 9174, 200],
#  [8104, 8043, 8064, 8688, 4561, 3266, 9755],
#  [4825],
#  [4253, 3763, 5814, 2210, 569, 730],
#  [9128, 1902, 1349, 2271],
#  [3329, 6567],
#  [4796, 5424, 4661, 8909],
#  [6664, 3484],
#  [5035, 2446, 3912],
#  [5695, 5053, 7317, 6335, 7625, 5311, 8509],
#  [4789, 3904],
#  [341, 9470, 7571, 1148, 6275, 6769],
#  [8813, 1655, 2080, 3343, 4117, 1952],
#  [8668, 777],
#  [6578, 2173, 2127, 1813, 7356],
#  [3645, 6266],
#  [1981, 2916, 4575, 1882, 3033, 2798, 162],
#  [1624, 6658, 849],
#  [7531, 854, 9705, 3700, 8331, 5353],
#  [769, 8506, 1206],
#  [3781, 4813, 9824],
#  [1718, 7589, 4483],
#  [7326, 2219, 6347],
#  [6066, 5623, 5623, 1107, 1708],
#  [3257],
#  [4207, 154],
#  [8657, 4922, 6709, 5127],
#  [6322, 4575, 5773, 4453],
#  [719, 38, 7210, 6812, 373],
#  [682, 6772, 7745, 719, 1148],
#  [8569, 752],
#  [7308, 7794, 7308, 3547, 5107, 3282],
#  [1836, 7929, 3947, 489, 3167, 7356, 2193],
#  [827, 4085, 8022, 9216],
#  [6532, 765, 769, 3940],
#  [9128, 2406],
#  [9690, 9981, 1944, 9981, 6161],
#  [1291, 3, 5432, 4245, 1514, 3371],
#  [9050, 996],
#  [1627, 4795, 8879],
#  [7735, 8196],
#  [649, 5613, 195, 8184, 4596, 2633, 8851],
#  [4506, 6369, 2939, 2174, 6365],
#  [7464, 9282, 8475, 3118, 8133, 7745],
#  [4687, 379, 9418, 1882, 942],
#  [9202, 435, 9613, 3546, 6266],
#  [8068, 8682, 9993, 4566, 8127],
#  [4628, 4926],
#  [8435, 6454, 4047],
#  [8554, 4256, 1232, 6088, 5401, 4483],
#  [8859, 8956, 1561, 6785, 3947],
#  [4926, 1981, 5873, 2923],
#  [1478, 5089, 3545],
#  [1221, 8594, 186, 1148],
#  [3033, 3270, 8335, 9694, 7846, 6275],
#  [8229],
#  [3373, 6873, 9931, 1650, 599, 4483],
#  [5493, 5044, 8099, 1650, 7307, 2816, 5493, 910, 2828],
#  [5384, 3212, 3558, 5558, 4882],
#  [9900, 4687, 6733, 4575, 74],
#  [5966, 1441, 2144, 76, 6378, 9216, 5493, 761],
#  [7704, 7637, 777, 898],
#  [368, 1295, 9496, 5280],
#  [4671, 702, 4595, 4575, 1850, 4898, 5927, 8602],
#  [5830, 5453, 4515, 5493, 7781, 417, 2828],
#  [6529, 5878, 6003, 5624, 5642, 7130],
#  [6269, 2877],
#  [5386, 4383, 6480, 3098, 460, 3267],
#  [8397, 8602, 4991, 9527, 789, 444],
#  [2995, 9496, 2346],
#  [719, 1479],
#  [5549],
#  [6321],
#  [2174, 6144, 3947, 2585, 1225],
#  [1172, 9597],
#  [4108, 1214, 4653],
#  [8725, 3881, 6669, 2127, 959, 2663],
#  [9048, 7309],
#  [5264, 7574, 9515, 1650, 1354, 6599, 5464, 771],
#  [9360, 7082, 3267],
#  [2981, 7528, 6296, 6480, 7555],
#  [5705, 9602, 8407, 3850, 5278],
#  [2031, 3443, 5338],
#  [5259, 435, 9613, 6245, 2692, 3050, 6135],
#  [6808, 9944],
#  [5493, 4648, 2818],
#  [7121, 9452, 6604],
#  [8602, 8085, 4132],
#  [620, 9273, 5191, 9690, 5378],
#  [5825, 5744, 6389, 7340, 7345, 7263],
#  [6315, 6204, 3329, 1207, 4483],
#  [2828, 417, 599, 9496, 1148],
#  [9910, 4770],
#  [1462, 6162, 4504, 3947, 5732],
#  [3406, 2928, 4273, 1650, 7781, 4483, 5189],
#  [4858, 4054, 5353, 7812, 1087, 3953, 5353],
#  [7811, 397, 719],
#  [6547, 2899, 367, 195],
#  [9577, 960],
#  [4946, 9210],
#  [5966, 6324, 1153, 5458],
#  [9003, 8602, 1148],
#  [3391, 7276, 2633, 7298, 9327, 8735, 7276],
#  [925, 3481, 8807, 7266, 2279, 145],
#  [7382, 4472, 5311, 9496],
#  [7155, 3609, 8162, 5820, 8162, 5297, 3379, 2378],
#  [3406, 5409],
#  [9704, 4683, 7444, 5493, 4483, 9094, 5745],
#  [9777, 4633, 7363, 9426],
#  [5705, 8807, 8059, 7811],
#  [5493, 7666, 7639, 6100, 7672],
#  [6624, 8431, 759, 4434],
#  [936],
#  [7554, 6047, 1430],
#  [9391, 5281, 1207, 3088, 7382, 4483],
#  [1184, 3721, 8532, 4427, 8602, 6986, 9339],
#  [1711, 4551],
#  [973, 1960, 5107, 3762],
#  [2680, 518, 8335, 4624, 417, 7802],
#  [3002, 4850, 2704, 601, 704],
#  [5124, 8068, 1148, 3231, 1527, 1979, 4483],
#  [9177, 6785, 3947, 4687, 6275],
#  [1381, 1332, 777, 3749, 9468, 2607],
#  [9226, 6567],
#  [5710, 7607],
#  [9797, 2932, 9496],
#  [1990, 9332],
#  [1081, 7919],
#  [3406, 8391, 1012],
#  [2331, 1159, 6733, 4925, 9837],
#  [9457, 4154],
#  [8041, 2632],
#  [5702, 7778, 612, 4085, 4013],
#  [1007, 4662, 7380, 5613, 8156, 7578, 8886, 3871, 3658],
#  [6236, 6809, 1529, 5705],
#  [3871, 3260, 9339, 9178],
#  [6872, 2612],
#  [165, 9322, 6298, 3546],
#  [7552],
#  [2611, 5317],
#  [3565, 3398, 5116, 5478, 1148],
#  [1190, 2324, 1404, 7569, 1527, 1979, 4483, 661, 2059],
#  [8796, 8428],
#  [9058],
#  [2048, 769, 1148],
#  [3622, 1880, 4541, 9349],
#  [7984, 3861, 4346, 4491],
#  [6258, 2479, 1027, 2406, 364, 306],
#  [6155, 800, 7041, 957],
#  [7671, 1826, 2424],
#  [7254, 7514, 9142, 2059],
#  [2986, 4117, 651, 653, 3865],
#  [7794, 6266, 7794, 7345],
#  [5945, 8671, 9806, 8671, 3739, 4072],
#  [7853, 9561, 9058, 769, 3931, 3804],
#  [7948, 5830, 8479, 2042],
#  [553, 8859, 6264, 719, 9772, 9556, 1437],
#  [4388, 1925, 5493, 7476],
#  [1461, 1461, 759, 1461, 6615, 2529],
#  [2458, 4480, 2205, 1206, 7507, 7803],
#  [7794],
#  [4762, 9395, 8552, 3919, 4403, 672],
#  [6999, 8195, 7816, 6451],
#  [4671, 9912],
#  [7794, 4671, 6620, 4671, 4252],
#  [9690, 6266, 9765, 39, 1306],
#  [3774, 6765, 3558, 5558, 4311, 2639],
#  [3565, 4437, 6447, 4687],
#  [2560, 5137, 9699],
#  [4504, 5261],
#  [1938, 7226, 4510, 6794, 6275, 7948, 6254, 7550],
#  [7954],
#  [2828, 4527, 6204, 435],
#  [849, 7796, 5945],
#  [6362, 625, 5988, 4095, 3267, 9630],
#  [1159, 6050, 7593, 3655, 2989, 2363, 6097, 2851, 8682],
#  [1508, 8099, 3246, 8074],
#  [4459, 2016, 2338, 6047],
#  [4687, 6887, 1245],
#  [9929, 39, 9178, 4347, 6447, 4687],
#  [4480, 5477],
#  [2606, 6088, 5339],
#  [1150],
#  [3314, 42, 3010, 9238, 6480, 1479, 4],
#  [7407, 2059, 9793, 1396, 1622, 2986, 7021],
#  [436, 6275, 6275, 373],
#  [2349, 9611],
#  [1905, 2899, 5994],
#  [5493, 1265, 3142, 9496, 8031, 229, 3565, 3823],
#  [7639, 9194, 3051, 4483],
#  [8177, 4671, 3559],
#  [9748, 1513, 5625, 3618, 9211, 9029, 1148],
#  [5956, 2406, 6620, 94, 7665],
#  [2406, 3126],
#  [5077, 2628, 3947],
#  [4014, 2892, 9049, 5193, 179],
#  [768, 6888, 9970, 5193, 3267],
#  [845, 6207, 6296],
#  [1500, 4702, 9190, 923, 5488],
#  [7675, 3082, 5508],
#  [3947, 7269, 5249],
#  [2827, 3519, 1792],
#  [5673, 1021, 1283],
#  [1875, 4117, 706, 7680, 9373],
#  [3215, 9725, 4014, 5571, 4464],
#  [8189, 1295, 384, 323, 680, 2039, 5631],
#  [9696, 2611, 7906, 9725, 2184],
#  [389, 4271],
#  [7524, 9033, 3050, 195, 3947, 4996],
#  [599, 6991, 4483, 3206, 2825],
#  [1479, 1033],
#  [9679, 4145, 3904],
#  [6339, 3246, 7815],
#  [2775, 4876, 788, 337, 769, 948, 8194],
#  [668, 5873, 4996, 8057, 4564],
#  [2567, 830, 3806, 5157, 6453, 7919],
#  [4505, 1130, 7919],
#  [2958],
#  [7269, 1719],
#  [2685, 3267, 2293, 3267, 1761],
#  [5107, 1012],
#  [243, 1408, 5107, 7307, 1012, 672],
#  [3440, 5454, 6873],
#  [6440, 2633, 33],
#  [7949, 5641, 2095, 727],
#  [323, 4519, 727, 9496, 7781],
#  [2634, 6988, 2488, 5705, 5264, 3369],
#  [8282, 2960],
#  [229, 4322, 5756],
#  [2016, 3947, 4134, 444, 919],
#  [5787, 4504, 3947],
#  [5370, 8175, 3398, 236, 3812],
#  [8667, 7389, 2441, 5237, 1087],
#  [9327, 3053, 599, 4483],
#  [6567, 5909, 567, 256],
#  [7672, 9425, 1708, 9467, 7672, 4759],
#  [3547, 7976, 2133, 7310, 672],
#  [623, 4504, 3947],
#  [5263, 6354, 9824, 9339],
#  [4825, 2174, 4515, 4632, 1498],
#  [2855, 9912, 5899],
#  [3860, 7699, 1370, 7794],
#  [216, 3384, 4849, 1153, 1764, 6480, 3696],
#  [2299, 8602, 864, 2387],
#  [5346, 6529, 3182],
#  [2174, 9327],
#  [9536, 4427, 3282],
#  [2272, 364, 4551],
#  [9546, 6553, 3904],
#  [6697, 4245, 3897],
#  [4739, 8602],
#  [9823, 8391, 286],
#  [7211, 7109, 551, 495, 9326, 769],
#  [7430, 3371],
#  [9252, 3788],
#  [4253, 8133, 7327, 5683, 8094, 3762],
#  [2095, 8068, 5493, 3106, 1813, 6732, 3947],
#  [6604, 4671, 2923],
#  [7673, 3546, 9210],
#  [2717, 7624],
#  [4113],
#  [6582, 8588],
#  [3402, 3909, 5493, 9956, 1148],
#  [5256, 8292, 39],
#  [5493, 761, 1054, 6232, 5873, 9995],
#  [3426, 6593, 1741, 460],
#  [6441, 5080, 4993, 4504, 3947, 5107, 5873],
#  [1797, 2710],
#  [6889, 3655, 5642],
#  [6687, 3257],
#  [9810, 6584, 2219, 268],
#  [7764, 4378, 834, 1470],
#  [1322, 2828, 1107, 9105],
#  [5270, 5756, 4859, 6924, 6733, 7531, 4901],
#  [1085, 8452, 463, 9392, 9174],
#  [5024, 4987, 6266, 6403, 7690, 7407],
#  [9689],
#  [9194, 9593, 9049, 5193],
#  [9282, 5670, 9354, 7780, 1119],
#  [4020, 3151, 4483, 5519, 1779, 2662, 1223, 1813],
#  [470, 2906, 6708],
#  [7906, 518, 2007],
#  [102, 536, 6444, 7919, 3806, 775, 8388],
#  [4747, 2347, 9177, 7794, 6359, 6620],
#  [900, 1563],
#  [8239, 8007, 797, 8616, 7745],
#  [7816, 8195, 9320, 2478, 9001, 851, 4791, 547],
#  [6890, 7847, 6031, 4403, 9822, 2346],
#  [6147, 1650, 7110, 672],
#  [5198, 2313],
#  [4586, 3310, 4946],
#  [4759, 5972, 3267, 4364, 9982, 5501, 7827, 9674],
#  [9327, 9999, 2633, 4620, 5353, 3231, 8189],
#  [1515, 6050, 3270, 769],
#  [3247, 1159, 6406, 1470, 5722],
#  [2603, 1148, 9496, 6414, 9062, 1915],
#  [2798, 1028, 6549],
#  [2729, 5532, 7147, 2162, 3126],
#  [5727, 7301, 477, 4898, 4151],
#  [6988, 4671, 9772, 6296, 4483],
#  [1970, 2681, 1149],
#  [7259, 4207, 3017],
#  [417, 9049, 5193],
#  [2036, 6733, 3352, 3721, 467],
#  [9719, 497, 9418, 3129, 6266, 7574],
#  [2828, 7126, 1774, 7667],
#  [6050, 8388],
#  [7945, 407, 7842, 672],
#  [2183, 9626, 8656, 2697, 3017, 5613, 195],
#  [2541, 8602, 33, 7524, 4946, 2245, 7981, 2184],
#  [341, 2184],
#  [1262, 417, 740, 9274],
#  [4207, 8367, 7107, 1328, 3308],
#  [830, 2776, 5642],
#  [5082],
#  [5705, 6769, 5479],
#  [8357],
#  [6145, 7334],
#  [3053, 4491, 7672, 599, 4483, 6620],
#  [2318, 8371, 6406, 8667],
#  [918, 7041],
#  [8784, 5521, 6483, 9596],
#  [6686, 732, 6406, 1148],
#  [8435, 6047, 2646],
#  [551, 364, 6128],
#  [1207, 2363, 7307, 672, 1148],
#  [8942, 9731, 2855, 769],
#  [4562, 5656, 6153, 2208, 4942, 6077, 1014, 2294],
#  [8668, 289, 3376, 4273],
#  [4687, 4991, 8602, 7745, 7442, 9718],
#  [7974, 3239, 110, 3205, 1108, 4796, 4849, 1153],
#  [9535, 3126, 4509, 2134, 3267],
#  [3291, 9356, 1086, 135, 195],
#  [9646, 7531, 5854, 2362, 8817, 5601, 359, 3694],
#  [3008, 8251, 26],
#  [8765, 9339, 169, 8947],
#  [2315, 9528, 7472, 3206, 9773, 3880],
#  [1279, 5840, 6991, 5193, 3267, 2299],
#  [3909, 6549, 7014, 4504, 3947],
#  [340, 599, 5477],
#  [1451, 5049, 7765],
#  [197, 332, 661, 1953, 8133, 6447],
#  [6902, 9760, 4824, 162, 2798, 4866],
#  [2634, 4529],
#  [6676, 830, 5632, 5873, 3267],
#  [254, 898, 5884, 6156, 4504, 3947],
#  [5101, 4515, 2244, 9128, 489],
#  [2095, 6859],
#  [3558, 6743, 3115, 4248, 2016, 5226],
#  [8131, 5107, 6425, 9282, 8133, 6670, 2768, 1147],
#  [2173, 4546, 2184, 7787, 8682, 4216, 5670],
#  [4078, 4687, 3366, 4928, 7794, 2193],
#  [5460, 5211, 4483],
#  [4013, 5127, 4071, 3455],
#  [7221, 9373, 4483],
#  [9765, 118, 6406, 1470, 612, 6500, 1021, 5478],
#  [5198, 8987, 9912, 1465, 5107, 1148],
#  [6899, 4724],
#  [8085, 9498, 6785, 3947],
#  [105, 1021, 3261, 7794],
#  [4121, 2968, 1887, 3254, 1960, 6251, 7543],
#  [3550, 3583, 846, 4103],
#  [4043, 9425, 465, 7781, 599, 6296, 4483],
#  [9022],
#  [6128, 8342, 9252, 8685, 1148, 353],
#  [5110, 3329, 9591],
#  [6122, 5631, 1148],
#  [9455],
#  [6003, 3126, 33, 2816, 6050, 8602, 9718],
#  [4919, 6794, 6330, 5293],
#  [2009, 1713, 6247, 578, 1153, 9746, 6492, 4074, 6161],
#  [8602, 7506, 8986, 6689],
#  [9696, 3676, 2406],
#  [5117, 1193, 340],
#  [8973, 9262, 3492],
#  [6194, 4515, 2681, 7683, 5239, 4967, 3897],
#  [6991, 8813],
#  [2921],
#  [599, 5383, 1383, 4483, 6098],
#  [9050, 4648, 6272, 2219, 9970, 3267, 4802],
#  [5983, 5868, 6426, 7495, 8530, 1526],
#  [4666, 7472, 3456, 4511, 3632, 9912, 2715, 4987, 5484],
#  [1148],
#  [8195, 2418, 3335, 7489],
#  [7496, 5873, 2639],
#  [9174, 1448],
#  [4403, 4222, 6266, 9797, 6022],
#  [8784, 5705, 5395],
#  [9540, 5335, 5493, 4702, 5238, 5146, 7794],
#  [1927, 2133, 7310, 1148, 3790, 3181, 3790, 415],
#  [3231, 3960, 5107, 5873, 9358, 4216],
#  [6808, 2256, 894, 9238, 3267],
#  [3535, 2632],
#  [6397, 7297, 2585, 7523],
#  [6453, 5521, 5970, 5591, 9778, 4151],
#  [3089, 7531, 5019],
#  [7386, 6222, 3051, 7036, 7414],
#  [8106],
#  [5279, 2739, 2120, 672],
#  [6266, 9591, 2219, 2563],
#  [7269, 5924, 7733, 9845],
#  [3057, 5782, 6529],
#  [894, 2916],
#  [6187, 5107, 2491],
#  [7945, 459, 2849, 672, 4427],
#  [7523, 3535, 7345, 5193, 5353],
#  [3037, 7097, 1850, 4226],
#  [4151, 2828, 3960, 680],
#  [2759, 9533, 4368, 8668, 7473, 5316],
#  [4987, 7493, 9731, 3947, 1148],
#  [1131, 5383, 5656, 769, 3749, 668, 4757],
#  [5693, 3947, 1067, 5296],
#  [3410, 6720, 4687, 379, 3751, 9722],
#  [7600, 3940, 1901],
#  [4427, 2277, 4687, 6275],
#  [9686],
#  [6022, 1666, 6450, 75, 3149, 489, 9183, 3947],
#  [2269, 45, 8602, 5313],
#  [1695, 5039, 1306],
#  [3960, 907],
#  [4560, 9400, 6920, 4795],
#  [2406, 3715],
#  [3135, 3546, 4682, 7362, 1836, 3204],
#  [1174, 3899, 599, 9496],
#  [313, 6396, 2205, 2599, 8602],
#  [8554, 4671, 6829, 7672],
#  [2858, 389],
#  [68, 1296],
#  [5112, 6772, 1665, 9339, 8712],
#  [3540],
#  [3836],
#  [8156, 7773, 4431, 8660],
#  [8794, 4207],
#  [5074, 1664, 6266, 2130, 7362, 1664],
#  [6369, 769, 1369],
#  [182, 9696],
#  [775, 5218, 3275, 2411, 8682, 8892],
#  [5786, 5291, 3064, 9690, 727, 816, 8860],
#  [9749, 3328, 8279],
#  [7268, 2204, 5723, 281, 9496],
#  [9941, 3909, 1380, 7917, 6275],
#  [1939, 3849, 5911],
#  [2828, 6814],
#  [604, 7461, 9543, 4491, 4617, 7595, 12, 1278],
#  [8804, 1370, 7794],
#  [7263, 323, 7653],
#  [3379, 4095],
#  [1511, 5906, 3231, 5949, 4483],
#  [3185, 3186, 7111],
#  [6720, 8977, 459, 3231, 5107, 5873, 4564, 6993],
#  [283, 7792, 7787, 36],
#  [2804, 2173],
#  [2768, 14, 4504, 3947],
#  [6254, 7382, 2194, 7414],
#  [1946, 1505, 2989, 6097],
#  [1961, 9117, 1650, 5705],
#  [2233, 1951],
#  [2922, 5102, 2563],
#  [4515, 2037, 3231, 3050, 7639, 460],
#  [9772, 6296, 3416, 4825, 7803, 9642, 6670],
#  [3947],
#  [5713, 3304, 610, 4575, 402, 6296, 5493, 8659],
#  [9379, 7837, 7956, 3845, 4639],
#  [9160, 7502, 3],
#  [2547, 9443, 3231, 9793, 4483],
#  [7937, 188],
#  [910, 9686, 1196],
#  [5986, 1850, 7036, 8880],
#  [4515, 7781, 9160, 5355, 5732, 5493, 1148],
#  [1412, 4020, 4775, 5101, 3390, 8671],
#  [9262, 7064, 839],
#  [4398, 1465],
#  [3953, 8990, 2406],
#  [9533, 4824, 675, 8487, 5353, 5482],
#  [6114, 7666, 2363, 2114],
#  [2906, 7380, 4575, 7361, 2184, 7395],
#  [7815, 6257, 604, 8239, 2553, 7735, 6661],
#  [9759, 5468, 4946, 3696, 4085],
#  [599, 9496, 4483, 7406],
#  [6246, 8097, 4383, 3270, 769],
#  [3009, 8013, 4510],
#  [4704, 6266, 3231, 7371, 6884, 8682, 4711, 5353],
#  [9722, 3282, 3762, 1737, 3535],
#  [3741, 2828],
#  [612, 588],
#  [9432],
#  [3280, 7745, 5302, 5873, 195],
#  [2241, 3679, 1033, 9874, 3267],
#  [5481, 7354],
#  [8357, 2828],
#  [4922, 1125, 3398, 3282, 3762, 3806, 775],
#  [5823, 3899, 751, 6444, 6075, 5823, 4208, 6444],
#  [6261, 460],
#  [1705, 1912, 1138, 5493, 4078],
#  [1664, 1570],
#  [7852, 5631],
#  [6617, 2406, 9451],
#  [8805, 7517, 2798, 3267],
#  [4824, 9878, 1952, 6120, 6670, 7595, 42],
#  [5878, 6408],
#  [1747, 8603, 2039, 2222],
#  [5949, 8602, 7745, 9527],
#  [1296, 2436],
#  [5154, 547, 6047],
#  [3328, 7941],
#  [3843, 3896, 8239],
#  [4128, 1742, 769, 5493, 6890, 2219, 2639],
#  [8911, 4756, 799, 2294, 6475],
#  [3017, 3191, 8537, 3696],
#  [5544, 1316, 5493, 4483, 3565, 5101],
#  [2301, 3830, 4775, 1705, 1758, 5404],
#  [7497, 3655],
#  [2250, 4653],
#  [1518, 4504, 3947],
#  [6650, 9563, 8972],
#  [2406, 1306, 399, 5117, 489, 5580],
#  [8699, 8275, 4898, 4151, 3871, 8275],
#  [719, 7643, 2355, 8012],
#  ...]

# %%
# Padding the sentences to be the same length
embedded_docs = pad_sequences(one_hot_rep,
                            padding= 'pre',
                            maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0 ...  910 9489 9986]
#  [   0    0    0 ... 8602 4814 9293]
#  [   0    0    0 ...    0    0 5983]
#  ...
#  [   0    0    0 ... 6785 5096 5315]
#  [   0    0    0 ...  384 8007 2916]
#  [   0    0    0 ... 7416 2828 2968]]

# %%
embedded_docs.shape
# Out:
# (331462, 12)

# %%
X_final = embedded_docs
y_final = np.array(df['state'])

# %%
print(type(np.array(df['state'])))
type(embedded_docs)
# Out:
# <class 'numpy.ndarray'>
# numpy.ndarray

# %%
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size =0.25, random_state=105)

# %%
# Creating Model
embedded_vector_features = 100
early_stopping = EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=5)

model = Sequential([
    (Embedding(voc_size, embedded_vector_features, input_length=sent_length)),
#     (LSTM(120, dropout=0.25, recurrent_dropout=0.25, return_sequences=True)),
    (Bidirectional(LSTM(120, dropout=0.35, recurrent_dropout=0.35, kernel_regularizer=l2(0.25), recurrent_regularizer=l2(0.325)))),
    (Dense(1, kernel_initializer = 'glorot_uniform', activation='sigmoid'))
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=21, batch_size = 80, callbacks=early_stopping)
# Out:
# Epoch 1/21
# 3108/3108 [==============================] - 116s 37ms/step - loss: 2.1249 - accuracy: 0.6244 - val_loss: 0.6385 - val_accuracy: 0.6492
# Epoch 2/21
# 3108/3108 [==============================] - 129s 41ms/step - loss: 0.6302 - accuracy: 0.6558 - val_loss: 0.6367 - val_accuracy: 0.6518
# Epoch 3/21
# 3108/3108 [==============================] - 116s 37ms/step - loss: 0.6229 - accuracy: 0.6607 - val_loss: 0.6339 - val_accuracy: 0.6504
# Epoch 4/21
# 3108/3108 [==============================] - 117s 38ms/step - loss: 0.6195 - accuracy: 0.6636 - val_loss: 0.6374 - val_accuracy: 0.6461
# Epoch 5/21
# 3108/3108 [==============================] - 120s 39ms/step - loss: 0.6178 - accuracy: 0.6646 - val_loss: 0.6356 - val_accuracy: 0.6481
# Epoch 6/21
# 3108/3108 [==============================] - 122s 39ms/step - loss: 0.6164 - accuracy: 0.6654 - val_loss: 0.6407 - val_accuracy: 0.6428
# Epoch 7/21
# 3108/3108 [==============================] - 118s 38ms/step - loss: 0.6157 - accuracy: 0.6660 - val_loss: 0.6396 - val_accuracy: 0.6416
# Epoch 8/21
# 3108/3108 [==============================] - 110s 35ms/step - loss: 0.6149 - accuracy: 0.6673 - val_loss: 0.6400 - val_accuracy: 0.6439

# %%
model.evaluate(X_test, y_test)
# Out:
# 2590/2590 [==============================] - 6s 2ms/step - loss: 0.6400 - accuracy: 0.6439
# [0.6399770379066467, 0.6439191102981567]
